# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json
# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 628

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = f"https://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&units=metric&q="

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['timezone']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | salinopolis
# Processing Record 2 of Set 1 | ternate
# Processing Record 3 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 5 of Set 1 | hobart
# Processing Record 6 of Set 1 | albany
# Processing Record 7 of Set 1 | tsaratanana
# Processing Record 8 of Set 1 | punta arenas
# Processing Record 9 of Set 1 | dwarka
# Processing Record 10 of Set 1 | bredasdorp
# Processing Record 11 of Set 1 | mehamn
# Processing Record 12 of Set 1 | jamestown
# Processing Record 13 of Set 1 | hami
# Processing Record 14 of Set 1 | butaritari
# Processing Record 15 of Set 1 | hermanus
# Processing Record 16 of Set 1 | kidal
# Processing Record 17 of Set 1 | anadyr
# Processing Record 18 of Set 1 | faanui
# Processing Record 19 of Set 1 | ginir
# Processing Record 20 of Set 1 | cherskiy
# Processing Record 21 of Set 1 | puerto ayora
# Processing Record 22 of Set 1 | qaanaaq
# Processing Record 23 of Set 1 | ushuaia
# Processing Record 24 of Set 1 | waipawa
# Processing Record 25 of Set 1 | geraldton
# Processing Record 26 of Set 1 | vaini
# Processing Record 27 of Set 1 | iqaluit
# Processing Record 28 of Set 1 | glasgow
# Processing Record 29 of Set 1 | bluff
# Processing Record 30 of Set 1 | busselton
# Processing Record 31 of Set 1 | coahuayana
# Processing Record 32 of Set 1 | marawi
# Processing Record 33 of Set 1 | rikitea
# Processing Record 34 of Set 1 | porto novo
# Processing Record 35 of Set 1 | provideniya
# Processing Record 36 of Set 1 | castro
# Processing Record 37 of Set 1 | desaguadero
# Processing Record 38 of Set 1 | bud
# Processing Record 39 of Set 1 | kodiak
# Processing Record 40 of Set 1 | esperance
# Processing Record 41 of Set 1 | east london
# Processing Record 42 of Set 1 | san quintin
# Processing Record 43 of Set 1 | kota kinabalu
# Processing Record 44 of Set 1 | mount isa
# Processing Record 45 of Set 1 | lesozavodsk
# Processing Record 46 of Set 1 | kamenskoye
# City not found. Skipping...
# Processing Record 47 of Set 1 | barbar
# City not found. Skipping...
# Processing Record 48 of Set 1 | usinsk
# Processing Record 49 of Set 1 | ixtapa
# Processing Record 50 of Set 1 | dikson
# Processing Record 0 of Set 2 | kapaa
# Processing Record 1 of Set 2 | hilo
# Processing Record 2 of Set 2 | severo-kurilsk
# Processing Record 3 of Set 2 | pevek
# Processing Record 4 of Set 2 | port alfred
# Processing Record 5 of Set 2 | shache
# Processing Record 6 of Set 2 | selma
# Processing Record 7 of Set 2 | kabinda
# Processing Record 8 of Set 2 | liling
# Processing Record 9 of Set 2 | lorengau
# Processing Record 10 of Set 2 | sakakah
# Processing Record 11 of Set 2 | torbay
# Processing Record 12 of Set 2 | new norfolk
# Processing Record 13 of Set 2 | atuona
# Processing Record 14 of Set 2 | dianopolis
# City not found. Skipping...
# Processing Record 15 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 16 of Set 2 | mataura
# Processing Record 17 of Set 2 | arroyo
# Processing Record 18 of Set 2 | anuradhapura
# Processing Record 19 of Set 2 | calancuasan
# City not found. Skipping...
# Processing Record 20 of Set 2 | nanortalik
# Processing Record 21 of Set 2 | walvis bay
# Processing Record 22 of Set 2 | inta
# Processing Record 23 of Set 2 | poitiers
# Processing Record 24 of Set 2 | mar del plata
# Processing Record 25 of Set 2 | yulara
# Processing Record 26 of Set 2 | umm durman
# City not found. Skipping...
# Processing Record 27 of Set 2 | luderitz
# Processing Record 28 of Set 2 | kitami
# Processing Record 29 of Set 2 | upernavik
# Processing Record 30 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 31 of Set 2 | karatu
# Processing Record 32 of Set 2 | cape town
# Processing Record 33 of Set 2 | clyde river
# Processing Record 34 of Set 2 | whitianga
# Processing Record 35 of Set 2 | sao joao da barra
# Processing Record 36 of Set 2 | tawkar
# City not found. Skipping...
# Processing Record 37 of Set 2 | bay roberts
# Processing Record 38 of Set 2 | rock springs
# Processing Record 39 of Set 2 | yellowknife
# Processing Record 40 of Set 2 | alofi
# Processing Record 41 of Set 2 | ust-omchug
# Processing Record 42 of Set 2 | bengkulu
# Processing Record 43 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 44 of Set 2 | avarua
# Processing Record 45 of Set 2 | alta floresta
# Processing Record 46 of Set 2 | quimperle
# Processing Record 47 of Set 2 | tuktoyaktuk
# Processing Record 48 of Set 2 | waingapu
# Processing Record 49 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 0 of Set 3 | tura
# Processing Record 1 of Set 3 | toora-khem
# Processing Record 2 of Set 3 | tautira
# Processing Record 3 of Set 3 | halden
# Processing Record 4 of Set 3 | san cristobal
# Processing Record 5 of Set 3 | thompson
# Processing Record 6 of Set 3 | pacific grove
# Processing Record 7 of Set 3 | rybnaya sloboda
# Processing Record 8 of Set 3 | pedernales
# Processing Record 9 of Set 3 | aflu
# City not found. Skipping...
# Processing Record 10 of Set 3 | kendari
# Processing Record 11 of Set 3 | lompoc
# Processing Record 12 of Set 3 | airai
# Processing Record 13 of Set 3 | tunxi
# City not found. Skipping...
# Processing Record 14 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 15 of Set 3 | kaitangata
# Processing Record 16 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 17 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 18 of Set 3 | margate
# Processing Record 19 of Set 3 | mbamba
# Processing Record 20 of Set 3 | korla
# Processing Record 21 of Set 3 | arraial do cabo
# Processing Record 22 of Set 3 | bethel
# Processing Record 23 of Set 3 | mrirt
# City not found. Skipping...
# Processing Record 24 of Set 3 | saint-augustin
# Processing Record 25 of Set 3 | barrow
# Processing Record 26 of Set 3 | ponta do sol
# Processing Record 27 of Set 3 | kamaishi
# Processing Record 28 of Set 3 | mahebourg
# Processing Record 29 of Set 3 | novikovo
# Processing Record 30 of Set 3 | sexsmith
# Processing Record 31 of Set 3 | khatanga
# Processing Record 32 of Set 3 | kainantu
# Processing Record 33 of Set 3 | brylivka
# Processing Record 34 of Set 3 | capim grosso
# Processing Record 35 of Set 3 | port keats
# Processing Record 36 of Set 3 | haines junction
# Processing Record 37 of Set 3 | west plains
# Processing Record 38 of Set 3 | hofn
# Processing Record 39 of Set 3 | praia da vitoria
# Processing Record 40 of Set 3 | sioux lookout
# Processing Record 41 of Set 3 | chuy
# Processing Record 42 of Set 3 | sault sainte marie
# Processing Record 43 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 44 of Set 3 | weinan
# Processing Record 45 of Set 3 | kavaratti
# Processing Record 46 of Set 3 | matlang
# Processing Record 47 of Set 3 | katsuura
# Processing Record 48 of Set 3 | taoudenni
# Processing Record 49 of Set 3 | cayenne
# Processing Record 0 of Set 4 | nioaque
# Processing Record 1 of Set 4 | cabo san lucas
# Processing Record 2 of Set 4 | batsfjord
# Processing Record 3 of Set 4 | itarema
# Processing Record 4 of Set 4 | svecha
# Processing Record 5 of Set 4 | christchurch
# Processing Record 6 of Set 4 | avera
# Processing Record 7 of Set 4 | primorsk
# Processing Record 8 of Set 4 | zhanatas
# City not found. Skipping...
# Processing Record 9 of Set 4 | kruisfontein
# Processing Record 10 of Set 4 | camacha
# Processing Record 11 of Set 4 | hurricane
# Processing Record 12 of Set 4 | macusani
# Processing Record 13 of Set 4 | charleston
# Processing Record 14 of Set 4 | krasnyy chikoy
# Processing Record 15 of Set 4 | goundam
# Processing Record 16 of Set 4 | burnie
# Processing Record 17 of Set 4 | kavieng
# Processing Record 18 of Set 4 | georgetown
# Processing Record 19 of Set 4 | valparaiso
# Processing Record 20 of Set 4 | qui nhon
# Processing Record 21 of Set 4 | port elizabeth
# Processing Record 22 of Set 4 | vikulovo
# Processing Record 23 of Set 4 | ribeira grande
# Processing Record 24 of Set 4 | tiksi
# Processing Record 25 of Set 4 | tsumeb
# Processing Record 26 of Set 4 | san-pedro
# Processing Record 27 of Set 4 | broken hill
# Processing Record 28 of Set 4 | kuusamo
# Processing Record 29 of Set 4 | hithadhoo
# Processing Record 30 of Set 4 | qandala
# Processing Record 31 of Set 4 | aklavik
# Processing Record 32 of Set 4 | xiangfan
# Processing Record 33 of Set 4 | calama
# Processing Record 34 of Set 4 | saint george
# Processing Record 35 of Set 4 | chilca
# Processing Record 36 of Set 4 | asau
# Processing Record 37 of Set 4 | outjo
# Processing Record 38 of Set 4 | ust-nera
# Processing Record 39 of Set 4 | kupang
# Processing Record 40 of Set 4 | kamenka
# Processing Record 41 of Set 4 | ouallam
# Processing Record 42 of Set 4 | guerrero negro
# Processing Record 43 of Set 4 | bathsheba
# Processing Record 44 of Set 4 | praia
# Processing Record 45 of Set 4 | markova
# Processing Record 46 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 47 of Set 4 | safwah
# City not found. Skipping...
# Processing Record 48 of Set 4 | alugan
# Processing Record 49 of Set 4 | la rioja
# Processing Record 0 of Set 5 | nara
# Processing Record 1 of Set 5 | jalpan
# Processing Record 2 of Set 5 | codrington
# Processing Record 3 of Set 5 | longyearbyen
# Processing Record 4 of Set 5 | ilam
# Processing Record 5 of Set 5 | biak
# Processing Record 6 of Set 5 | tasiilaq
# Processing Record 7 of Set 5 | lebu
# Processing Record 8 of Set 5 | tucuma
# Processing Record 9 of Set 5 | hihifo
# City not found. Skipping...
# Processing Record 10 of Set 5 | namatanai
# Processing Record 11 of Set 5 | tuggurt
# City not found. Skipping...
# Processing Record 12 of Set 5 | saldanha
# Processing Record 13 of Set 5 | muros
# Processing Record 14 of Set 5 | fevralsk
# City not found. Skipping...
# Processing Record 15 of Set 5 | inuvik
# Processing Record 16 of Set 5 | xiaolingwei
# Processing Record 17 of Set 5 | senneterre
# Processing Record 18 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 19 of Set 5 | athabasca
# Processing Record 20 of Set 5 | saskylakh
# Processing Record 21 of Set 5 | alegrete
# Processing Record 22 of Set 5 | diego de almagro
# Processing Record 23 of Set 5 | orotukan
# Processing Record 24 of Set 5 | narsaq
# Processing Record 25 of Set 5 | souillac
# Processing Record 26 of Set 5 | miri
# Processing Record 27 of Set 5 | nikolskoye
# Processing Record 28 of Set 5 | cedar city
# Processing Record 29 of Set 5 | richards bay
# Processing Record 30 of Set 5 | sanford
# Processing Record 31 of Set 5 | wakkanai
# Processing Record 32 of Set 5 | misratah
# Processing Record 33 of Set 5 | hovd
# Processing Record 34 of Set 5 | pathein
# Processing Record 35 of Set 5 | pitimbu
# Processing Record 36 of Set 5 | yerbogachen
# Processing Record 37 of Set 5 | auki
# Processing Record 38 of Set 5 | half moon bay
# Processing Record 39 of Set 5 | vao
# Processing Record 40 of Set 5 | flin flon
# Processing Record 41 of Set 5 | gravdal
# Processing Record 42 of Set 5 | svetlogorsk
# Processing Record 43 of Set 5 | tilichiki
# Processing Record 44 of Set 5 | talara
# Processing Record 45 of Set 5 | karratha
# Processing Record 46 of Set 5 | cockburn town
# Processing Record 47 of Set 5 | svetlyy
# Processing Record 48 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 49 of Set 5 | mildura
# Processing Record 0 of Set 6 | tripoli
# Processing Record 1 of Set 6 | kijang
# Processing Record 2 of Set 6 | naryan-mar
# Processing Record 3 of Set 6 | middle island
# Processing Record 4 of Set 6 | caconda
# Processing Record 5 of Set 6 | pitea
# Processing Record 6 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 7 of Set 6 | nabire
# Processing Record 8 of Set 6 | ugoofaaru
# Processing Record 9 of Set 6 | ilulissat
# Processing Record 10 of Set 6 | ozernovskiy
# Processing Record 11 of Set 6 | olafsvik
# Processing Record 12 of Set 6 | tessalit
# Processing Record 13 of Set 6 | araguatins
# City not found. Skipping...
# Processing Record 14 of Set 6 | corinto
# Processing Record 15 of Set 6 | poum
# Processing Record 16 of Set 6 | melchor de mencos
# Processing Record 17 of Set 6 | mahibadhoo
# Processing Record 18 of Set 6 | pisco
# Processing Record 19 of Set 6 | finschhafen
# Processing Record 20 of Set 6 | turan
# Processing Record 21 of Set 6 | yar-sale
# Processing Record 22 of Set 6 | hasaki
# Processing Record 23 of Set 6 | buqayq
# City not found. Skipping...
# Processing Record 24 of Set 6 | sulurpeta
# City not found. Skipping...
# Processing Record 25 of Set 6 | meadow lake
# Processing Record 26 of Set 6 | fortuna
# Processing Record 27 of Set 6 | suwalki
# Processing Record 28 of Set 6 | lusambo
# Processing Record 29 of Set 6 | ko samui
# Processing Record 30 of Set 6 | sorland
# Processing Record 31 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 32 of Set 6 | husavik
# Processing Record 33 of Set 6 | mbulu
# Processing Record 34 of Set 6 | dingle
# Processing Record 35 of Set 6 | nyurba
# Processing Record 36 of Set 6 | belaya gora
# Processing Record 37 of Set 6 | elko
# Processing Record 38 of Set 6 | sitka
# Processing Record 39 of Set 6 | opuwo
# Processing Record 40 of Set 6 | mastic beach
# Processing Record 41 of Set 6 | tenenkou
# Processing Record 42 of Set 6 | dyurtyuli
# Processing Record 43 of Set 6 | lebane
# Processing Record 44 of Set 6 | mizdah
# Processing Record 45 of Set 6 | shahrud
# Processing Record 46 of Set 6 | sivas
# Processing Record 47 of Set 6 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 48 of Set 6 | saint-philippe
# Processing Record 49 of Set 6 | maltahohe
# Processing Record 0 of Set 7 | marica
# Processing Record 1 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 2 of Set 7 | tirumullaivasal
# Processing Record 3 of Set 7 | porto santo
# Processing Record 4 of Set 7 | elmira
# Processing Record 5 of Set 7 | quatre cocos
# Processing Record 6 of Set 7 | salalah
# Processing Record 7 of Set 7 | jiddah
# City not found. Skipping...
# Processing Record 8 of Set 7 | tulagi
# Processing Record 9 of Set 7 | khonuu
# City not found. Skipping...
# Processing Record 10 of Set 7 | east retford
# Processing Record 11 of Set 7 | tshela
# Processing Record 12 of Set 7 | rio gallegos
# Processing Record 13 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 14 of Set 7 | pingliang
# Processing Record 15 of Set 7 | den helder
# Processing Record 16 of Set 7 | bilibino
# Processing Record 17 of Set 7 | akyab
# Processing Record 18 of Set 7 | zhangye
# Processing Record 19 of Set 7 | banda aceh
# Processing Record 20 of Set 7 | nouakchott
# Processing Record 21 of Set 7 | caravelas
# Processing Record 22 of Set 7 | nogliki
# Processing Record 23 of Set 7 | manoel urbano
# Processing Record 24 of Set 7 | nizamabad
# Processing Record 25 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 26 of Set 7 | atar
# Processing Record 27 of Set 7 | saint-francois
# Processing Record 28 of Set 7 | portland
# Processing Record 29 of Set 7 | quelimane
# Processing Record 30 of Set 7 | pirovskoye
# Processing Record 31 of Set 7 | kununurra
# Processing Record 32 of Set 7 | rocha
# Processing Record 33 of Set 7 | koubia
# Processing Record 34 of Set 7 | college
# Processing Record 35 of Set 7 | knysna
# Processing Record 36 of Set 7 | khilok
# Processing Record 37 of Set 7 | coihaique
# Processing Record 38 of Set 7 | mizan teferi
# Processing Record 39 of Set 7 | venaria reale
# Processing Record 40 of Set 7 | thinadhoo
# Processing Record 41 of Set 7 | maua
# Processing Record 42 of Set 7 | santa maria del oro
# Processing Record 43 of Set 7 | cao bang
# Processing Record 44 of Set 7 | glenwood springs
# Processing Record 45 of Set 7 | victoria
# Processing Record 46 of Set 7 | norman wells
# Processing Record 47 of Set 7 | mumford
# Processing Record 48 of Set 7 | flinders
# Processing Record 49 of Set 7 | yialos
# City not found. Skipping...
# Processing Record 0 of Set 8 | strezhevoy
# Processing Record 1 of Set 8 | ponta delgada
# Processing Record 2 of Set 8 | puri
# Processing Record 3 of Set 8 | northam
# Processing Record 4 of Set 8 | birao
# Processing Record 5 of Set 8 | pontianak
# Processing Record 6 of Set 8 | petawawa
# Processing Record 7 of Set 8 | yagodnoye
# Processing Record 8 of Set 8 | ancud
# Processing Record 9 of Set 8 | moranbah
# Processing Record 10 of Set 8 | yinchuan
# Processing Record 11 of Set 8 | havoysund
# Processing Record 12 of Set 8 | robertsport
# Processing Record 13 of Set 8 | berdigestyakh
# Processing Record 14 of Set 8 | phan thiet
# Processing Record 15 of Set 8 | vaitape
# Processing Record 16 of Set 8 | ust-koksa
# Processing Record 17 of Set 8 | huntsville
# Processing Record 18 of Set 8 | kromy
# Processing Record 19 of Set 8 | savalou
# Processing Record 20 of Set 8 | pokhara
# Processing Record 21 of Set 8 | totma
# Processing Record 22 of Set 8 | bongandanga
# Processing Record 23 of Set 8 | fare
# Processing Record 24 of Set 8 | chokurdakh
# Processing Record 25 of Set 8 | goderich
# Processing Record 26 of Set 8 | padang
# Processing Record 27 of Set 8 | makakilo city
# Processing Record 28 of Set 8 | taltal
# Processing Record 29 of Set 8 | gizo
# Processing Record 30 of Set 8 | naifaru
# Processing Record 31 of Set 8 | lagoa
# Processing Record 32 of Set 8 | brentwood
# Processing Record 33 of Set 8 | rio grande
# Processing Record 34 of Set 8 | cutervo
# Processing Record 35 of Set 8 | mataram
# Processing Record 36 of Set 8 | eldorado
# Processing Record 37 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record 38 of Set 8 | hervey bay
# Processing Record 39 of Set 8 | concepcion del oro
# Processing Record 40 of Set 8 | naco
# Processing Record 41 of Set 8 | kurilsk
# Processing Record 42 of Set 8 | burley
# Processing Record 43 of Set 8 | lithakia
# Processing Record 44 of Set 8 | sochi
# Processing Record 45 of Set 8 | olinda
# Processing Record 46 of Set 8 | laguna
# Processing Record 47 of Set 8 | edd
# Processing Record 48 of Set 8 | manzil tamim
# City not found. Skipping...
# Processing Record 49 of Set 8 | pailon
# Processing Record 0 of Set 9 | gidole
# Processing Record 1 of Set 9 | brae
# Processing Record 2 of Set 9 | mirnyy
# Processing Record 3 of Set 9 | pueblo
# Processing Record 4 of Set 9 | kailahun
# Processing Record 5 of Set 9 | champerico
# Processing Record 6 of Set 9 | piuma
# Processing Record 7 of Set 9 | takoradi
# Processing Record 8 of Set 9 | port blair
# Processing Record 9 of Set 9 | harper
# Processing Record 10 of Set 9 | porto empedocle
# Processing Record 11 of Set 9 | baie-comeau
# Processing Record 12 of Set 9 | sao filipe
# Processing Record 13 of Set 9 | arman
# Processing Record 14 of Set 9 | mount gambier
# Processing Record 15 of Set 9 | broome
# Processing Record 16 of Set 9 | kahului
# Processing Record 17 of Set 9 | steamboat springs
# Processing Record 18 of Set 9 | narasannapeta
# Processing Record 19 of Set 9 | gamba
# Processing Record 20 of Set 9 | yining
# Processing Record 21 of Set 9 | humberto de campos
# Processing Record 22 of Set 9 | verkhoyansk
# Processing Record 23 of Set 9 | pangnirtung
# Processing Record 24 of Set 9 | labuhan
# Processing Record 25 of Set 9 | merauke
# Processing Record 26 of Set 9 | phanat nikhom
# Processing Record 27 of Set 9 | sungairaya
# Processing Record 28 of Set 9 | urumqi
# Processing Record 29 of Set 9 | saint-pierre
# Processing Record 30 of Set 9 | paita
# Processing Record 31 of Set 9 | tuatapere
# Processing Record 32 of Set 9 | micheweni
# Processing Record 33 of Set 9 | cidreira
# Processing Record 34 of Set 9 | lavrentiya
# Processing Record 35 of Set 9 | bal-os
# Processing Record 36 of Set 9 | fort nelson
# Processing Record 37 of Set 9 | port hardy
# Processing Record 38 of Set 9 | klaksvik
# Processing Record 39 of Set 9 | alice springs
# Processing Record 40 of Set 9 | chippewa falls
# Processing Record 41 of Set 9 | qinzhou
# Processing Record 42 of Set 9 | san jeronimo
# Processing Record 43 of Set 9 | vallenar
# Processing Record 44 of Set 9 | humboldt
# Processing Record 45 of Set 9 | dzaoudzi
# Processing Record 46 of Set 9 | diamantina
# Processing Record 47 of Set 9 | bonavista
# Processing Record 48 of Set 9 | karakulino
# Processing Record 49 of Set 9 | homer
# Processing Record 0 of Set 10 | zhicheng
# Processing Record 1 of Set 10 | carnarvon
# Processing Record 2 of Set 10 | durango
# Processing Record 3 of Set 10 | tecoanapa
# Processing Record 4 of Set 10 | springhill
# Processing Record 5 of Set 10 | changzhou
# Processing Record 6 of Set 10 | san rafael
# Processing Record 7 of Set 10 | crailsheim
# Processing Record 8 of Set 10 | talcahuano
# Processing Record 9 of Set 10 | qasigiannguit
# Processing Record 10 of Set 10 | komsomolskiy
# Processing Record 11 of Set 10 | brewster
# Processing Record 12 of Set 10 | jumla
# Processing Record 13 of Set 10 | zhumadian
# Processing Record 14 of Set 10 | guasdualito
# Processing Record 15 of Set 10 | gambela
# Processing Record 16 of Set 10 | mujiayingzi
# Processing Record 17 of Set 10 | tsihombe
# City not found. Skipping...
# Processing Record 18 of Set 10 | bolonchen
# City not found. Skipping...
# Processing Record 19 of Set 10 | oktyabrskoye
# Processing Record 20 of Set 10 | kashan
# Processing Record 21 of Set 10 | marsa matruh
# Processing Record 22 of Set 10 | mikuni
# Processing Record 23 of Set 10 | petauke
# Processing Record 24 of Set 10 | cabra
# Processing Record 25 of Set 10 | armacao de pera
# Processing Record 26 of Set 10 | talnakh
# Processing Record 27 of Set 10 | timmins
# Processing Record 28 of Set 10 | uglovka
# Processing Record 29 of Set 10 | radovitskiy
# Processing Record 30 of Set 10 | san carlos de bariloche
# Processing Record 31 of Set 10 | launceston
# Processing Record 32 of Set 10 | rovaniemi
# Processing Record 33 of Set 10 | nyaunglebin
# Processing Record 34 of Set 10 | caibarien
# Processing Record 35 of Set 10 | udachnyy
# Processing Record 36 of Set 10 | grindavik
# Processing Record 37 of Set 10 | kazalinsk
# City not found. Skipping...
# Processing Record 38 of Set 10 | sao gabriel da cachoeira
# Processing Record 39 of Set 10 | port shepstone
# Processing Record 40 of Set 10 | sabha
# Processing Record 41 of Set 10 | ilhabela
# Processing Record 42 of Set 10 | valencia
# Processing Record 43 of Set 10 | san jose
# Processing Record 44 of Set 10 | santo antonio do taua
# Processing Record 45 of Set 10 | cap malheureux
# Processing Record 46 of Set 10 | touros
# Processing Record 47 of Set 10 | port lincoln
# Processing Record 48 of Set 10 | mindelo
# Processing Record 49 of Set 10 | acobamba
# Processing Record 0 of Set 11 | santander
# Processing Record 1 of Set 11 | derzhavinsk
# Processing Record 2 of Set 11 | mananara
# Processing Record 3 of Set 11 | honiara
# Processing Record 4 of Set 11 | anchorage
# Processing Record 5 of Set 11 | motygino
# Processing Record 6 of Set 11 | mackay
# Processing Record 7 of Set 11 | tibiri
# Processing Record 8 of Set 11 | acapulco
# Processing Record 9 of Set 11 | mikkeli
# Processing Record 10 of Set 11 | leh
# Processing Record 11 of Set 11 | lata
# Processing Record 12 of Set 11 | bosaso
# Processing Record 13 of Set 11 | hong gai
# Processing Record 14 of Set 11 | samana
# Processing Record 15 of Set 11 | nishihara
# Processing Record 16 of Set 11 | panaba
# Processing Record 17 of Set 11 | virginia beach
# Processing Record 18 of Set 11 | poso
# Processing Record 19 of Set 11 | tazmalt
# Processing Record 20 of Set 11 | suamico
# Processing Record 21 of Set 11 | lasa
# Processing Record 22 of Set 11 | vardo
# Processing Record 23 of Set 11 | chingirlau
# Processing Record 24 of Set 11 | irshava
# Processing Record 25 of Set 11 | great bend
# Processing Record 26 of Set 11 | chegutu
# Processing Record 27 of Set 11 | katherine
# Processing Record 28 of Set 11 | chivacoa
# Processing Record 29 of Set 11 | dzhusaly
# City not found. Skipping...
# Processing Record 30 of Set 11 | chimore
# Processing Record 31 of Set 11 | weyburn
# Processing Record 32 of Set 11 | abu dhabi
# Processing Record 33 of Set 11 | kawambwa
# Processing Record 34 of Set 11 | lyskovo
# Processing Record 35 of Set 11 | oranjemund
# Processing Record 36 of Set 11 | cadillac
# Processing Record 37 of Set 11 | tarudant
# City not found. Skipping...
# Processing Record 38 of Set 11 | mersing
# Processing Record 39 of Set 11 | vilhena
# Processing Record 40 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 41 of Set 11 | bonthe
# Processing Record 42 of Set 11 | maniitsoq
# Processing Record 43 of Set 11 | burriana
# Processing Record 44 of Set 11 | sabaudia
# Processing Record 45 of Set 11 | aketi
# Processing Record 46 of Set 11 | voh
# Processing Record 47 of Set 11 | san patricio
# Processing Record 48 of Set 11 | los llanos de aridane
# Processing Record 49 of Set 11 | changji
# Processing Record 0 of Set 12 | saint-joseph
# Processing Record 1 of Set 12 | nantucket
# Processing Record 2 of Set 12 | sira
# Processing Record 3 of Set 12 | hauterive
# Processing Record 4 of Set 12 | rantepao
# Processing Record 5 of Set 12 | hohoe
# Processing Record 6 of Set 12 | manadhoo
# Processing Record 7 of Set 12 | mandalgovi
# Processing Record 8 of Set 12 | jishou
# Processing Record 9 of Set 12 | ilebo
# Processing Record 10 of Set 12 | tulum
# Processing Record 11 of Set 12 | havre
# Processing Record 12 of Set 12 | antofagasta
# Processing Record 13 of Set 12 | yangshe
# Processing Record 14 of Set 12 | kalmunai
# Processing Record 15 of Set 12 | matamoros
# Processing Record 16 of Set 12 | raudeberg
# Processing Record 17 of Set 12 | mulchen
# Processing Record 18 of Set 12 | innisfail
# Processing Record 19 of Set 12 | coquimbo
# Processing Record 20 of Set 12 | trujillo
# Processing Record 21 of Set 12 | vila franca do campo
# Processing Record 22 of Set 12 | gogrial
# Processing Record 23 of Set 12 | sena madureira
# Processing Record 24 of Set 12 | mobaye
# Processing Record 25 of Set 12 | vero beach
# Processing Record 26 of Set 12 | lichinga
# Processing Record 27 of Set 12 | doka
# Processing Record 28 of Set 12 | constitucion
# Processing Record 29 of Set 12 | greensburg
# Processing Record 30 of Set 12 | ust-maya
# Processing Record 31 of Set 12 | bowen
# Processing Record 32 of Set 12 | bambous virieux
# Processing Record 33 of Set 12 | santa rosa
# Processing Record 34 of Set 12 | samalaeulu
# City not found. Skipping...
# Processing Record 35 of Set 12 | jining
# Processing Record 36 of Set 12 | concepcion del uruguay
# Processing Record 37 of Set 12 | ballina
# Processing Record 38 of Set 12 | gasa
# Processing Record 39 of Set 12 | uniontown
# Processing Record 40 of Set 12 | charters towers
# Processing Record 41 of Set 12 | iyo
# Processing Record 42 of Set 12 | taloqan
# Processing Record 43 of Set 12 | ahome
# Processing Record 44 of Set 12 | ladispoli
# Processing Record 45 of Set 12 | akom
# Processing Record 46 of Set 12 | romny
# Processing Record 47 of Set 12 | abnub
# Processing Record 48 of Set 12 | ivanava
# Processing Record 49 of Set 12 | takaka
# Processing Record 0 of Set 13 | buariki
# City not found. Skipping...
# Processing Record 1 of Set 13 | morondava
# Processing Record 2 of Set 13 | jinzhou
# Processing Record 3 of Set 13 | wanning
# Processing Record 4 of Set 13 | hanna
# Processing Record 5 of Set 13 | the valley
# Processing Record 6 of Set 13 | katangli
# Processing Record 7 of Set 13 | nome
# Processing Record 8 of Set 13 | comodoro rivadavia
# Processing Record 9 of Set 13 | ayorou
# Processing Record 10 of Set 13 | ramhormoz
# Processing Record 11 of Set 13 | sambava
# Processing Record 12 of Set 13 | majalengka
# Processing Record 13 of Set 13 | vila velha
# Processing Record 14 of Set 13 | mocambique
# City not found. Skipping...
# Processing Record 15 of Set 13 | iquique
# Processing Record 16 of Set 13 | erzurum
# Processing Record 17 of Set 13 | remscheid
# Processing Record 18 of Set 13 | berlevag
# Processing Record 19 of Set 13 | kutum
# Processing Record 20 of Set 13 | raga
# Processing Record 21 of Set 13 | ouidah
# Processing Record 22 of Set 13 | ngunguru
# Processing Record 23 of Set 13 | inhambane
# Processing Record 24 of Set 13 | naze
# Processing Record 25 of Set 13 | ocos
# Processing Record 26 of Set 13 | djibo
# Processing Record 27 of Set 13 | la ronge
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data
# Out:
# [{'City': 'salinopolis',
#   'Lat': -0.6136,
#   'Lng': -47.3561,
#   'Max Temp': 30.49,
#   'Humidity': 58,
#   'Cloudiness': 27,
#   'Wind Speed': 3.86,
#   'Country': 'BR',
#   'Date': -10800},
#  {'City': 'ternate',
#   'Lat': 0.8,
#   'Lng': 127.4,
#   'Max Temp': 27.36,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 0.95,
#   'Country': 'ID',
#   'Date': 32400},
#  {'City': 'hobart',
#   'Lat': -42.8794,
#   'Lng': 147.3294,
#   'Max Temp': 10.7,
#   'Humidity': 94,
#   'Cloudiness': 12,
#   'Wind Speed': 1.62,
#   'Country': 'AU',
#   'Date': 39600},
#  {'City': 'albany',
#   'Lat': 42.6001,
#   'Lng': -73.9662,
#   'Max Temp': 21.81,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 0.89,
#   'Country': 'US',
#   'Date': -18000},
#  {'City': 'tsaratanana',
#   'Lat': -16.7833,
#   'Lng': 47.65,
#   'Max Temp': 27.97,
#   'Humidity': 47,
#   'Cloudiness': 66,
#   'Wind Speed': 2.31,
#   'Country': 'MG',
#   'Date': 10800},
#  {'City': 'punta arenas',
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Max Temp': 13.06,
#   'Humidity': 67,
#   'Cloudiness': 0,
#   'Wind Speed': 4.12,
#   'Country': 'CL',
#   'Date': -10800},
#  {'City': 'dwarka',
#   'Lat': 22.2394,
#   'Lng': 68.9678,
#   'Max Temp': 26.98,
#   'Humidity': 67,
#   'Cloudiness': 83,
#   'Wind Speed': 3.85,
#   'Country': 'IN',
#   'Date': 19800},
#  {'City': 'bredasdorp',
#   'Lat': -34.5322,
#   'Lng': 20.0403,
#   'Max Temp': 19.15,
#   'Humidity': 81,
#   'Cloudiness': 51,
#   'Wind Speed': 5.41,
#   'Country': 'ZA',
#   'Date': 7200},
#  {'City': 'mehamn',
#   'Lat': 71.0357,
#   'Lng': 27.8492,
#   'Max Temp': 2.97,
#   'Humidity': 65,
#   'Cloudiness': 75,
#   'Wind Speed': 4.63,
#   'Country': 'NO',
#   'Date': 3600},
#  {'City': 'jamestown',
#   'Lat': 42.097,
#   'Lng': -79.2353,
#   'Max Temp': 21.68,
#   'Humidity': 69,
#   'Cloudiness': 100,
#   'Wind Speed': 8.23,
#   'Country': 'US',
#   'Date': -18000},
#  {'City': 'hami',
#   'Lat': 42.8,
#   'Lng': 93.45,
#   'Max Temp': 9.87,
#   'Humidity': 23,
#   'Cloudiness': 99,
#   'Wind Speed': 0.95,
#   'Country': 'CN',
#   'Date': 28800},
#  {'City': 'butaritari',
#   'Lat': 3.0707,
#   'Lng': 172.7902,
#   'Max Temp': 25.99,
#   'Humidity': 75,
#   'Cloudiness': 96,
#   'Wind Speed': 2.61,
#   'Country': 'KI',
#   'Date': 43200},
#  {'City': 'hermanus',
#   'Lat': -34.4187,
#   'Lng': 19.2345,
#   'Max Temp': 22.67,
#   'Humidity': 70,
#   'Cloudiness': 42,
#   'Wind Speed': 6.52,
#   'Country': 'ZA',
#   'Date': 7200},
#  {'City': 'kidal',
#   'Lat': 18.4411,
#   'Lng': 1.4078,
#   'Max Temp': 29.96,
#   'Humidity': 11,
#   'Cloudiness': 0,
#   'Wind Speed': 4.12,
#   'Country': 'ML',
#   'Date': 0},
#  {'City': 'anadyr',
#   'Lat': 64.75,
#   'Lng': 177.4833,
#   'Max Temp': -0.72,
#   'Humidity': 80,
#   'Cloudiness': 0,
#   'Wind Speed': 4,
#   'Country': 'RU',
#   'Date': 43200},
#  {'City': 'faanui',
#   'Lat': -16.4833,
#   'Lng': -151.75,
#   'Max Temp': 26.1,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 9.25,
#   'Country': 'PF',
#   'Date': -36000},
#  {'City': 'ginir',
#   'Lat': 7.1333,
#   'Lng': 40.7,
#   'Max Temp': 16.37,
#   'Humidity': 60,
#   'Cloudiness': 84,
#   'Wind Speed': 0.6,
#   'Country': 'ET',
#   'Date': 10800},
#  {'City': 'cherskiy',
#   'Lat': 68.75,
#   'Lng': 161.3,
#   'Max Temp': -20.56,
#   'Humidity': 98,
#   'Cloudiness': 97,
#   'Wind Speed': 2.73,
#   'Country': 'RU',
#   'Date': 39600},
#  {'City': 'puerto ayora',
#   'Lat': -0.7393,
#   'Lng': -90.3518,
#   'Max Temp': 24.98,
#   'Humidity': 72,
#   'Cloudiness': 33,
#   'Wind Speed': 4.93,
#   'Country': 'EC',
#   'Date': -21600},
#  {'City': 'qaanaaq',
#   'Lat': 77.484,
#   'Lng': -69.3632,
#   'Max Temp': -15.52,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 2.27,
#   'Country': 'GL',
#   'Date': -14400},
#  {'City': 'ushuaia',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 8.81,
#   'Humidity': 81,
#   'Cloudiness': 75,
#   'Wind Speed': 2.57,
#   'Country': 'AR',
#   'Date': -10800},
#  {'City': 'waipawa',
#   'Lat': -41.4122,
#   'Lng': 175.5153,
#   'Max Temp': 6.89,
#   'Humidity': 90,
#   'Cloudiness': 0,
#   'Wind Speed': 2.63,
#   'Country': 'NZ',
#   'Date': 46800},
#  {'City': 'geraldton',
#   'Lat': -28.7667,
#   'Lng': 114.6,
#   'Max Temp': 18.23,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 6.69,
#   'Country': 'AU',
#   'Date': 28800},
#  {'City': 'vaini',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 22.09,
#   'Humidity': 83,
#   'Cloudiness': 20,
#   'Wind Speed': 2.57,
#   'Country': 'TO',
#   'Date': 46800},
#  {'City': 'iqaluit',
#   'Lat': 63.7506,
#   'Lng': -68.5145,
#   'Max Temp': -7.15,
#   'Humidity': 58,
#   'Cloudiness': 100,
#   'Wind Speed': 3.09,
#   'Country': 'CA',
#   'Date': -18000},
#  {'City': 'glasgow',
#   'Lat': 55.8652,
#   'Lng': -4.2576,
#   'Max Temp': 11.23,
#   'Humidity': 84,
#   'Cloudiness': 75,
#   'Wind Speed': 4.63,
#   'Country': 'GB',
#   'Date': 0},
#  {'City': 'bluff',
#   'Lat': -46.6,
#   'Lng': 168.3333,
#   'Max Temp': 9.01,
#   'Humidity': 78,
#   'Cloudiness': 76,
#   'Wind Speed': 5.52,
#   'Country': 'NZ',
#   'Date': 46800},
#  {'City': 'busselton',
#   'Lat': -33.65,
#   'Lng': 115.3333,
#   'Max Temp': 14.23,
#   'Humidity': 84,
#   'Cloudiness': 67,
#   'Wind Speed': 4.82,
#   'Country': 'AU',
#   'Date': 28800},
#  {'City': 'coahuayana',
#   'Lat': 18.7333,
#   'Lng': -103.6833,
#   'Max Temp': 29.71,
#   'Humidity': 65,
#   'Cloudiness': 35,
#   'Wind Speed': 1.55,
#   'Country': 'MX',
#   'Date': -21600},
#  {'City': 'marawi',
#   'Lat': 7.9986,
#   'Lng': 124.2928,
#   'Max Temp': 20.46,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 0.83,
#   'Country': 'PH',
#   'Date': 28800},
#  {'City': 'rikitea',
#   'Lat': -23.1203,
#   'Lng': -134.9692,
#   'Max Temp': 21.91,
#   'Humidity': 71,
#   'Cloudiness': 95,
#   'Wind Speed': 5.54,
#   'Country': 'PF',
#   'Date': -32400},
#  {'City': 'porto novo',
#   'Lat': 6.4965,
#   'Lng': 2.6036,
#   'Max Temp': 27.88,
#   'Humidity': 73,
#   'Cloudiness': 90,
#   'Wind Speed': 2.76,
#   'Country': 'BJ',
#   'Date': 3600},
#  {'City': 'provideniya',
#   'Lat': 64.3833,
#   'Lng': -173.3,
#   'Max Temp': 1.99,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 4.52,
#   'Country': 'RU',
#   'Date': 43200},
#  {'City': 'castro',
#   'Lat': -24.7911,
#   'Lng': -50.0119,
#   'Max Temp': 19.42,
#   'Humidity': 45,
#   'Cloudiness': 17,
#   'Wind Speed': 1.51,
#   'Country': 'BR',
#   'Date': -10800},
#  {'City': 'desaguadero',
#   'Lat': -16.5656,
#   'Lng': -69.0417,
#   'Max Temp': 14.91,
#   'Humidity': 24,
#   'Cloudiness': 0,
#   'Wind Speed': 6.57,
#   'Country': 'PE',
#   'Date': -18000},
#  {'City': 'bud',
#   'Lat': 39.447,
#   'Lng': -86.1758,
#   'Max Temp': 17.08,
#   'Humidity': 65,
#   'Cloudiness': 22,
#   'Wind Speed': 5.19,
#   'Country': 'US',
#   'Date': -18000},
#  {'City': 'kodiak',
#   'Lat': 57.79,
#   'Lng': -152.4072,
#   'Max Temp': -0.27,
#   'Humidity': 43,
#   'Cloudiness': 0,
#   'Wind Speed': 6.69,
#   'Country': 'US',
#   'Date': -32400},
#  {'City': 'esperance',
#   'Lat': -33.8667,
#   'Lng': 121.9,
#   'Max Temp': 14.69,
#   'Humidity': 83,
#   'Cloudiness': 77,
#   'Wind Speed': 6.45,
#   'Country': 'AU',
#   'Date': 28800},
#  {'City': 'east london',
#   'Lat': -33.0153,
#   'Lng': 27.9116,
#   'Max Temp': 21.52,
#   'Humidity': 73,
#   'Cloudiness': 20,
#   'Wind Speed': 5.66,
#   'Country': 'ZA',
#   'Date': 7200},
#  {'City': 'san quintin',
#   'Lat': 30.4833,
#   'Lng': -115.95,
#   'Max Temp': 17.91,
#   'Humidity': 68,
#   'Cloudiness': 0,
#   'Wind Speed': 3.11,
#   'Country': 'MX',
#   'Date': -28800},
#  {'City': 'kota kinabalu',
#   'Lat': 5.9749,
#   'Lng': 116.0724,
#   'Max Temp': 24.99,
#   'Humidity': 94,
#   'Cloudiness': 20,
#   'Wind Speed': 1.54,
#   'Country': 'MY',
#   'Date': 28800},
#  {'City': 'mount isa',
#   'Lat': -20.7333,
#   'Lng': 139.5,
#   'Max Temp': 23.87,
#   'Humidity': 64,
#   'Cloudiness': 75,
#   'Wind Speed': 4.12,
#   'Country': 'AU',
#   'Date': 36000},
#  {'City': 'lesozavodsk',
#   'Lat': 45.4794,
#   'Lng': 133.4244,
#   'Max Temp': -2.04,
#   'Humidity': 62,
#   'Cloudiness': 9,
#   'Wind Speed': 3.21,
#   'Country': 'RU',
#   'Date': 36000},
#  {'City': 'usinsk',
#   'Lat': 65.9939,
#   'Lng': 57.5281,
#   'Max Temp': -0.04,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 3.53,
#   'Country': 'RU',
#   'Date': 10800},
#  {'City': 'ixtapa',
#   'Lat': 20.7,
#   'Lng': -105.2,
#   'Max Temp': 26.79,
#   'Humidity': 73,
#   'Cloudiness': 0,
#   'Wind Speed': 2.57,
#   'Country': 'MX',
#   'Date': -21600},
#  {'City': 'dikson',
#   'Lat': 73.5069,
#   'Lng': 80.5464,
#   'Max Temp': -12.71,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 4.84,
#   'Country': 'RU',
#   'Date': 25200},
#  {'City': 'kapaa',
#   'Lat': 22.0752,
#   'Lng': -159.319,
#   'Max Temp': 25.61,
#   'Humidity': 81,
#   'Cloudiness': 40,
#   'Wind Speed': 6.69,
#   'Country': 'US',
#   'Date': -36000},
#  {'City': 'hilo',
#   'Lat': 19.7297,
#   'Lng': -155.09,
#   'Max Temp': 22.36,
#   'Humidity': 86,
#   'Cloudiness': 0,
#   'Wind Speed': 3.09,
#   'Country': 'US',
#   'Date': -36000},
#  {'City': 'severo-kurilsk',
#   'Lat': 50.6789,
#   'Lng': 156.125,
#   'Max Temp': 1.68,
#   'Humidity': 67,
#   'Cloudiness': 79,
#   'Wind Speed': 5.55,
#   'Country': 'RU',
#   'Date': 39600},
#  {'City': 'pevek',
#   'Lat': 69.7008,
#   'Lng': 170.3133,
#   'Max Temp': -11.9,
#   'Humidity': 92,
#   'Cloudiness': 70,
#   'Wind Speed': 4.16,
#   'Country': 'RU',
#   'Date': 43200},
#  {'City': 'port alfred',
#   'Lat': -33.5906,
#   'Lng': 26.891,
#   'Max Temp': 21.21,
#   'Humidity': 78,
#   'Cloudiness': 30,
#   'Wind Speed': 3.13,
#   'Country': 'ZA',
#   'Date': 7200},
#  {'City': 'shache',
#   'Lat': 38.4167,
#   'Lng': 77.2406,
#   'Max Temp': 8.01,
#   'Humidity': 33,
#   'Cloudiness': 52,
#   'Wind Speed': 0.21,
#   'Country': 'CN',
#   'Date': 28800},
#  {'City': 'selma',
#   'Lat': 36.5708,
#   'Lng': -119.6121,
#   'Max Temp': 14.57,
#   'Humidity': 70,
#   'Cloudiness': 100,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Date': -28800},
#  {'City': 'kabinda',
#   'Lat': -6.1333,
#   'Lng': 24.4833,
#   'Max Temp': 20.26,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 1.28,
#   'Country': 'CD',
#   'Date': 7200},
#  {'City': 'liling',
#   'Lat': 27.6667,
#   'Lng': 113.5,
#   'Max Temp': 15.98,
#   'Humidity': 65,
#   'Cloudiness': 0,
#   'Wind Speed': 1.39,
#   'Country': 'CN',
#   'Date': 28800},
#  {'City': 'lorengau',
#   'Lat': -2.0226,
#   'Lng': 147.2712,
#   'Max Temp': 26.97,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 1,
#   'Country': 'PG',
#   'Date': 36000},
#  {'City': 'sakakah',
#   'Lat': 29.9697,
#   'Lng': 40.2064,
#   'Max Temp': 23.76,
#   'Humidity': 37,
#   'Cloudiness': 5,
#   'Wind Speed': 4.64,
#   'Country': 'SA',
#   'Date': 10800},
#  {'City': 'torbay',
#   'Lat': 47.6666,
#   'Lng': -52.7314,
#   'Max Temp': 8.49,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 2.06,
#   'Country': 'CA',
#   'Date': -12600},
#  {'City': 'new norfolk',
#   'Lat': -42.7826,
#   'Lng': 147.0587,
#   'Max Temp': 10.5,
#   'Humidity': 64,
#   'Cloudiness': 12,
#   'Wind Speed': 1.24,
#   'Country': 'AU',
#   'Date': 39600},
#  {'City': 'atuona',
#   'Lat': -9.8,
#   'Lng': -139.0333,
#   'Max Temp': 24.82,
#   'Humidity': 69,
#   'Cloudiness': 93,
#   'Wind Speed': 4.78,
#   'Country': 'PF',
#   'Date': -34200},
#  {'City': 'mataura',
#   'Lat': -46.1927,
#   'Lng': 168.8643,
#   'Max Temp': 3.84,
#   'Humidity': 97,
#   'Cloudiness': 23,
#   'Wind Speed': 1.52,
#   'Country': 'NZ',
#   'Date': 46800},
#  {'City': 'arroyo',
#   'Lat': 41.6096,
#   'Lng': -4.7969,
#   'Max Temp': 15.89,
#   'Humidity': 79,
#   'Cloudiness': 20,
#   'Wind Speed': 6.69,
#   'Country': 'ES',
#   'Date': 3600},
#  {'City': 'anuradhapura',
#   'Lat': 8.3565,
#   'Lng': 80.4173,
#   'Max Temp': 22.48,
#   'Humidity': 92,
#   'Cloudiness': 79,
#   'Wind Speed': 2.09,
#   'Country': 'LK',
#   'Date': 19800},
#  {'City': 'nanortalik',
#   'Lat': 60.1432,
#   'Lng': -45.2371,
#   'Max Temp': 0.32,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 1.78,
#   'Country': 'GL',
#   'Date': -10800},
#  {'City': 'walvis bay',
#   'Lat': -22.9575,
#   'Lng': 14.5053,
#   'Max Temp': 18.53,
#   'Humidity': 77,
#   'Cloudiness': 0,
#   'Wind Speed': 1.54,
#   'Country': 'NA',
#   'Date': 7200},
#  {'City': 'inta',
#   'Lat': 66.0317,
#   'Lng': 60.1659,
#   'Max Temp': -1.88,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 4.37,
#   'Country': 'RU',
#   'Date': 10800},
#  {'City': 'poitiers',
#   'Lat': 46.5833,
#   'Lng': 0.3333,
#   'Max Temp': 14.58,
#   'Humidity': 55,
#   'Cloudiness': 75,
#   'Wind Speed': 5.14,
#   'Country': 'FR',
#   'Date': 3600},
#  {'City': 'mar del plata',
#   'Lat': -38.0023,
#   'Lng': -57.5575,
#   'Max Temp': 24.9,
#   'Humidity': 79,
#   'Cloudiness': 0,
#   'Wind Speed': 11.62,
#   'Country': 'AR',
#   'Date': -10800},
#  {'City': 'yulara',
#   'Lat': -25.2406,
#   'Lng': 130.9889,
#   'Max Temp': 25.87,
#   'Humidity': 17,
#   'Cloudiness': 87,
#   'Wind Speed': 7.02,
#   'Country': 'AU',
#   'Date': 34200},
#  {'City': 'luderitz',
#   'Lat': -26.6481,
#   'Lng': 15.1594,
#   'Max Temp': 18.55,
#   'Humidity': 77,
#   'Cloudiness': 75,
#   'Wind Speed': 2.83,
#   'Country': 'NA',
#   'Date': 7200},
#  {'City': 'kitami',
#   'Lat': 43.8031,
#   'Lng': 143.8908,
#   'Max Temp': 1.73,
#   'Humidity': 83,
#   'Cloudiness': 35,
#   'Wind Speed': 1.84,
#   'Country': 'JP',
#   'Date': 32400},
#  {'City': 'upernavik',
#   'Lat': 72.7868,
#   'Lng': -56.1549,
#   'Max Temp': -7.58,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 2.61,
#   'Country': 'GL',
#   'Date': -10800},
#  {'City': 'karatu',
#   'Lat': -3.3333,
#   'Lng': 35.6667,
#   'Max Temp': 21.07,
#   'Humidity': 56,
#   'Cloudiness': 52,
#   'Wind Speed': 2.27,
#   'Country': 'TZ',
#   'Date': 10800},
#  {'City': 'cape town',
#   'Lat': -33.9258,
#   'Lng': 18.4232,
#   'Max Temp': 22.37,
#   'Humidity': 65,
#   'Cloudiness': 0,
#   'Wind Speed': 3.6,
#   'Country': 'ZA',
#   'Date': 7200},
#  {'City': 'clyde river',
#   'Lat': 70.4692,
#   'Lng': -68.5914,
#   'Max Temp': -14.87,
#   'Humidity': 51,
#   'Cloudiness': 20,
#   'Wind Speed': 3.09,
#   'Country': 'CA',
#   'Date': -18000},
#  {'City': 'whitianga',
#   'Lat': -36.8333,
#   'Lng': 175.7,
#   'Max Temp': 14.22,
#   'Humidity': 66,
#   'Cloudiness': 89,
#   'Wind Speed': 4.26,
#   'Country': 'NZ',
#   'Date': 46800},
#  {'City': 'sao joao da barra',
#   'Lat': -21.6403,
#   'Lng': -41.0511,
#   'Max Temp': 26.05,
#   'Humidity': 60,
#   'Cloudiness': 23,
#   'Wind Speed': 6.92,
#   'Country': 'BR',
#   'Date': -10800},
#  {'City': 'bay roberts',
#   'Lat': 47.5999,
#   'Lng': -53.2648,
#   'Max Temp': 8.92,
#   'Humidity': 92,
#   'Cloudiness': 97,
#   'Wind Speed': 0.45,
#   'Country': 'CA',
#   'Date': -12600},
#  {'City': 'rock springs',
#   'Lat': 41.5875,
#   'Lng': -109.2029,
#   'Max Temp': 0.69,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Date': -25200},
#  {'City': 'yellowknife',
#   'Lat': 62.456,
#   'Lng': -114.3525,
#   'Max Temp': -23.58,
#   'Humidity': 84,
#   'Cloudiness': 20,
#   'Wind Speed': 3.09,
#   'Country': 'CA',
#   'Date': -25200},
#  {'City': 'alofi',
#   'Lat': -19.0595,
#   'Lng': -169.9187,
#   'Max Temp': 18.94,
#   'Humidity': 94,
#   'Cloudiness': 16,
#   'Wind Speed': 2.06,
#   'Country': 'NU',
#   'Date': -39600},
#  {'City': 'ust-omchug',
#   'Lat': 61.15,
#   'Lng': 149.6333,
#   'Max Temp': -16.28,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 1.33,
#   'Country': 'RU',
#   'Date': 39600},
#  {'City': 'bengkulu',
#   'Lat': -3.8004,
#   'Lng': 102.2655,
#   'Max Temp': 24.67,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 1.84,
#   'Country': 'ID',
#   'Date': 25200},
#  {'City': 'avarua',
#   'Lat': -21.2078,
#   'Lng': -159.775,
#   'Max Temp': 21.03,
#   'Humidity': 83,
#   'Cloudiness': 3,
#   'Wind Speed': 1.54,
#   'Country': 'CK',
#   'Date': -36000},
#  {'City': 'alta floresta',
#   'Lat': -9.8756,
#   'Lng': -56.0861,
#   'Max Temp': 32.9,
#   'Humidity': 46,
#   'Cloudiness': 40,
#   'Wind Speed': 1.03,
#   'Country': 'BR',
#   'Date': -14400},
#  {'City': 'quimperle',
#   'Lat': 47.8667,
#   'Lng': -3.55,
#   'Max Temp': 14.86,
#   'Humidity': 80,
#   'Cloudiness': 75,
#   'Wind Speed': 10.8,
#   'Country': 'FR',
#   'Date': 3600},
#  {'City': 'tuktoyaktuk',
#   'Lat': 69.4541,
#   'Lng': -133.0374,
#   'Max Temp': -15,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 4.63,
#   'Country': 'CA',
#   'Date': -25200},
#  {'City': 'waingapu',
#   'Lat': -9.6567,
#   'Lng': 120.2641,
#   'Max Temp': 27.17,
#   'Humidity': 79,
#   'Cloudiness': 79,
#   'Wind Speed': 1.35,
#   'Country': 'ID',
#   'Date': 28800},
#  {'City': 'tura',
#   'Lat': 25.5198,
#   'Lng': 90.2201,
#   'Max Temp': 18.82,
#   'Humidity': 93,
#   'Cloudiness': 0,
#   'Wind Speed': 1.45,
#   'Country': 'IN',
#   'Date': 19800},
#  {'City': 'toora-khem',
#   'Lat': 52.4675,
#   'Lng': 96.11,
#   'Max Temp': -4.38,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 1.27,
#   'Country': 'RU',
#   'Date': 25200},
#  {'City': 'tautira',
#   'Lat': -17.7333,
#   'Lng': -149.15,
#   'Max Temp': 24.07,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 10.81,
#   'Country': 'PF',
#   'Date': -36000},
#  {'City': 'halden',
#   'Lat': 59.1226,
#   'Lng': 11.3871,
#   'Max Temp': 7.57,
#   'Humidity': 91,
#   'Cloudiness': 46,
#   'Wind Speed': 4.11,
#   'Country': 'NO',
#   'Date': 3600},
#  {'City': 'san cristobal',
#   'Lat': 7.7669,
#   'Lng': -72.225,
#   'Max Temp': 28.1,
#   'Humidity': 57,
#   'Cloudiness': 71,
#   'Wind Speed': 2.47,
#   'Country': 'VE',
#   'Date': -14400},
#  {'City': 'thompson',
#   'Lat': 55.7435,
#   'Lng': -97.8558,
#   'Max Temp': -3.91,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 6.17,
#   'Country': 'CA',
#   'Date': -21600},
#  {'City': 'pacific grove',
#   'Lat': 36.6177,
#   'Lng': -121.9166,
#   'Max Temp': 14.45,
#   'Humidity': 79,
#   'Cloudiness': 75,
#   'Wind Speed': 2.57,
#   'Country': 'US',
#   'Date': -28800},
#  {'City': 'rybnaya sloboda',
#   'Lat': 55.4613,
#   'Lng': 50.1409,
#   'Max Temp': -2.8,
#   'Humidity': 87,
#   'Cloudiness': 44,
#   'Wind Speed': 3.23,
#   'Country': 'RU',
#   'Date': 10800},
#  {'City': 'pedernales',
#   'Lat': 18.0384,
#   'Lng': -71.744,
#   'Max Temp': 27.66,
#   'Humidity': 68,
#   'Cloudiness': 5,
#   'Wind Speed': 3.94,
#   'Country': 'DO',
#   'Date': -14400},
#  {'City': 'kendari',
#   'Lat': -3.945,
#   'Lng': 122.4989,
#   'Max Temp': 24.28,
#   'Humidity': 91,
#   'Cloudiness': 98,
#   'Wind Speed': 1.03,
#   'Country': 'ID',
#   'Date': 28800},
#  {'City': 'lompoc',
#   'Lat': 34.6391,
#   'Lng': -120.4579,
#   'Max Temp': 14.22,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 2.57,
#   'Country': 'US',
#   'Date': -28800},
#  {'City': 'airai',
#   'Lat': -8.9266,
#   'Lng': 125.4092,
#   'Max Temp': 16.06,
#   'Humidity': 81,
#   'Cloudiness': 83,
#   'Wind Speed': 0.82,
#   'Country': 'TL',
#   'Date': 32400},
#  {'City': 'kaitangata',
#   'Lat': -46.2817,
#   'Lng': 169.8464,
#   'Max Temp': 5.51,
#   'Humidity': 90,
#   'Cloudiness': 31,
#   'Wind Speed': 2.86,
#   'Country': 'NZ',
#   'Date': 46800},
#  {'City': 'margate',
#   'Lat': 51.3813,
#   'Lng': 1.3862,
#   'Max Temp': 12.39,
#   'Humidity': 92,
#   'Cloudiness': 98,
#   'Wind Speed': 11.32,
#   'Country': 'GB',
#   'Date': 0},
#  {'City': 'mbamba',
#   'Lat': 9.9833,
#   'Lng': 13.1,
#   'Max Temp': 26.72,
#   'Humidity': 29,
#   'Cloudiness': 100,
#   'Wind Speed': 0.94,
#   'Country': 'NG',
#   'Date': 3600},
#  {'City': 'korla',
#   'Lat': 41.7597,
#   'Lng': 86.1469,
#   'Max Temp': 10.46,
#   'Humidity': 36,
#   'Cloudiness': 100,
#   'Wind Speed': 1.56,
#   'Country': 'CN',
#   'Date': 28800},
#  {'City': 'arraial do cabo',
#   'Lat': -22.9661,
#   'Lng': -42.0278,
#   'Max Temp': 24.98,
#   'Humidity': 60,
#   'Cloudiness': 0,
#   'Wind Speed': 7.72,
#   'Country': 'BR',
#   'Date': -10800},
#  {'City': 'bethel',
#   'Lat': 41.3712,
#   'Lng': -73.414,
#   'Max Temp': 23.44,
#   'Humidity': 72,
#   'Cloudiness': 75,
#   'Wind Speed': 4.12,
#   'Country': 'US',
#   'Date': -18000},
#  {'City': 'saint-augustin',
#   'Lat': 51.226,
#   'Lng': -58.6502,
#   'Max Temp': 4.63,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 7.61,
#   'Country': 'CA',
#   'Date': -14400},
#  {'City': 'barrow',
#   'Lat': 71.2906,
#   'Lng': -156.7887,
#   'Max Temp': -13.99,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 10.29,
#   'Country': 'US',
#   'Date': -32400},
#  {'City': 'ponta do sol',
#   'Lat': 32.6667,
#   'Lng': -17.1,
#   'Max Temp': 22.78,
#   'Humidity': 88,
#   'Cloudiness': 74,
#   'Wind Speed': 1.58,
#   'Country': 'PT',
#   'Date': 0},
#  {'City': 'kamaishi',
#   'Lat': 39.2667,
#   'Lng': 141.8833,
#   'Max Temp': 8.79,
#   'Humidity': 74,
#   'Cloudiness': 4,
#   'Wind Speed': 2.54,
#   'Country': 'JP',
#   'Date': 32400},
#  {'City': 'mahebourg',
#   'Lat': -20.4081,
#   'Lng': 57.7,
#   'Max Temp': 24.16,
#   'Humidity': 73,
#   'Cloudiness': 40,
#   'Wind Speed': 2.57,
#   'Country': 'MU',
#   'Date': 14400},
#  {'City': 'novikovo',
#   'Lat': 51.1537,
#   'Lng': 37.8879,
#   'Max Temp': 1.41,
#   'Humidity': 79,
#   'Cloudiness': 31,
#   'Wind Speed': 2.35,
#   'Country': 'RU',
#   'Date': 10800},
#  {'City': 'sexsmith',
#   'Lat': 55.35,
#   'Lng': -118.786,
#   'Max Temp': -14.36,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 3.09,
#   'Country': 'CA',
#   'Date': -25200},
#  {'City': 'khatanga',
#   'Lat': 71.9667,
#   'Lng': 102.5,
#   'Max Temp': -29.7,
#   'Humidity': 99,
#   'Cloudiness': 46,
#   'Wind Speed': 2.08,
#   'Country': 'RU',
#   'Date': 25200},
#  {'City': 'kainantu',
#   'Lat': -6.2887,
#   'Lng': 145.8655,
#   'Max Temp': 15.63,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 1.3,
#   'Country': 'PG',
#   'Date': 36000},
#  {'City': 'brylivka',
#   'Lat': 46.4248,
#   'Lng': 33.1472,
#   'Max Temp': 6.9,
#   'Humidity': 70,
#   'Cloudiness': 99,
#   'Wind Speed': 6.3,
#   'Country': 'UA',
#   'Date': 7200},
#  {'City': 'capim grosso',
#   'Lat': -11.3811,
#   'Lng': -40.0128,
#   'Max Temp': 27.7,
#   'Humidity': 49,
#   'Cloudiness': 92,
#   'Wind Speed': 4.89,
#   'Country': 'BR',
#   'Date': -10800},
#  {'City': 'port keats',
#   'Lat': -14.25,
#   'Lng': 129.55,
#   'Max Temp': 28.67,
#   'Humidity': 71,
#   'Cloudiness': 9,
#   'Wind Speed': 3.31,
#   'Country': 'AU',
#   'Date': 34200},
#  {'City': 'haines junction',
#   'Lat': 60.7522,
#   'Lng': -137.5108,
#   'Max Temp': -17.03,
#   'Humidity': 66,
#   'Cloudiness': 40,
#   'Wind Speed': 0.51,
#   'Country': 'CA',
#   'Date': -25200},
#  {'City': 'west plains',
#   'Lat': 36.7281,
#   'Lng': -91.8524,
#   'Max Temp': 17.21,
#   'Humidity': 70,
#   'Cloudiness': 0,
#   'Wind Speed': 4.02,
#   'Country': 'US',
#   'Date': -21600},
#  {'City': 'hofn',
#   'Lat': 64.2539,
#   'Lng': -15.2082,
#   'Max Temp': 5.01,
#   'Humidity': 60,
#   'Cloudiness': 100,
#   'Wind Speed': 7.2,
#   'Country': 'IS',
#   'Date': 0},
#  {'City': 'praia da vitoria',
#   'Lat': 38.7333,
#   'Lng': -27.0667,
#   'Max Temp': 21.14,
#   'Humidity': 64,
#   'Cloudiness': 40,
#   'Wind Speed': 4.38,
#   'Country': 'PT',
#   'Date': -3600},
#  {'City': 'sioux lookout',
#   'Lat': 50.1001,
#   'Lng': -91.917,
#   'Max Temp': 0.04,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 3.09,
#   'Country': 'CA',
#   'Date': -21600},
#  {'City': 'chuy',
#   'Lat': -33.6971,
#   'Lng': -53.4616,
#   'Max Temp': 20.3,
#   'Humidity': 61,
#   'Cloudiness': 11,
#   'Wind Speed': 6.4,
#   'Country': 'UY',
#   'Date': -10800},
#  {'City': 'sault sainte marie',
#   'Lat': 46.5168,
#   'Lng': -84.3333,
#   'Max Temp': 9.9,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 4.63,
#   'Country': 'CA',
#   'Date': -18000},
#  {'City': 'weinan',
#   'Lat': 34.5036,
#   'Lng': 109.5089,
#   'Max Temp': 13.8,
#   'Humidity': 66,
#   'Cloudiness': 0,
#   'Wind Speed': 1.24,
#   'Country': 'CN',
#   'Date': 28800},
#  {'City': 'kavaratti',
#   'Lat': 10.5669,
#   'Lng': 72.642,
#   'Max Temp': 27.68,
#   'Humidity': 76,
#   'Cloudiness': 2,
#   'Wind Speed': 3.12,
#   'Country': 'IN',
#   'Date': 19800},
#  {'City': 'matlang',
#   'Lat': 10.8902,
#   'Lng': 124.4554,
#   'Max Temp': 26.59,
#   'Humidity': 83,
#   'Cloudiness': 97,
#   'Wind Speed': 2.19,
#   'Country': 'PH',
#   'Date': 28800},
#  {'City': 'katsuura',
#   'Lat': 35.1333,
#   'Lng': 140.3,
#   'Max Temp': 15.49,
#   'Humidity': 64,
#   'Cloudiness': 55,
#   'Wind Speed': 3.62,
#   'Country': 'JP',
#   'Date': 32400},
#  {'City': 'taoudenni',
#   'Lat': 22.6783,
#   'Lng': -3.9836,
#   'Max Temp': 31.69,
#   'Humidity': 10,
#   'Cloudiness': 0,
#   'Wind Speed': 4.59,
#   'Country': 'ML',
#   'Date': 0},
#  {'City': 'cayenne',
#   'Lat': 4.9333,
#   'Lng': -52.3333,
#   'Max Temp': 33.02,
#   'Humidity': 52,
#   'Cloudiness': 20,
#   'Wind Speed': 2.57,
#   'Country': 'GF',
#   'Date': -10800},
#  {'City': 'nioaque',
#   'Lat': -21.1353,
#   'Lng': -55.83,
#   'Max Temp': 32.58,
#   'Humidity': 19,
#   'Cloudiness': 1,
#   'Wind Speed': 2.63,
#   'Country': 'BR',
#   'Date': -14400},
#  {'City': 'cabo san lucas',
#   'Lat': 22.8909,
#   'Lng': -109.9124,
#   'Max Temp': 26.14,
#   'Humidity': 64,
#   'Cloudiness': 5,
#   'Wind Speed': 0.89,
#   'Country': 'MX',
#   'Date': -25200},
#  {'City': 'batsfjord',
#   'Lat': 70.6345,
#   'Lng': 29.7185,
#   'Max Temp': 2.88,
#   'Humidity': 75,
#   'Cloudiness': 75,
#   'Wind Speed': 3.6,
#   'Country': 'NO',
#   'Date': 3600},
#  {'City': 'itarema',
#   'Lat': -2.9248,
#   'Lng': -39.9167,
#   'Max Temp': 30.57,
#   'Humidity': 58,
#   'Cloudiness': 87,
#   'Wind Speed': 7.77,
#   'Country': 'BR',
#   'Date': -10800},
#  {'City': 'svecha',
#   'Lat': 58.2785,
#   'Lng': 47.5164,
#   'Max Temp': -2.65,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 2.18,
#   'Country': 'RU',
#   'Date': 10800},
#  {'City': 'christchurch',
#   'Lat': -43.5333,
#   'Lng': 172.6333,
#   'Max Temp': 12.11,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 3.09,
#   'Country': 'NZ',
#   'Date': 46800},
#  {'City': 'avera',
#   'Lat': 33.194,
#   'Lng': -82.5271,
#   'Max Temp': 25.77,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 2.16,
#   'Country': 'US',
#   'Date': -18000},
#  {'City': 'primorsk',
#   'Lat': 46.7348,
#   'Lng': 36.3443,
#   'Max Temp': 6.43,
#   'Humidity': 70,
#   'Cloudiness': 50,
#   'Wind Speed': 7.03,
#   'Country': 'UA',
#   'Date': 7200},
#  {'City': 'kruisfontein',
#   'Lat': -34.0033,
#   'Lng': 24.7314,
#   'Max Temp': 21.05,
#   'Humidity': 74,
#   'Cloudiness': 25,
#   'Wind Speed': 8.48,
#   'Country': 'ZA',
#   'Date': 7200},
#  {'City': 'camacha',
#   'Lat': 33.0833,
#   'Lng': -16.3333,
#   'Max Temp': 19.68,
#   'Humidity': 73,
#   'Cloudiness': 20,
#   'Wind Speed': 3.09,
#   'Country': 'PT',
#   'Date': 0},
#  {'City': 'hurricane',
#   'Lat': 37.1753,
#   'Lng': -113.2899,
#   'Max Temp': 14.19,
#   'Humidity': 29,
#   'Cloudiness': 7,
#   'Wind Speed': 1.03,
#   'Country': 'US',
#   'Date': -25200},
#  {'City': 'macusani',
#   'Lat': -14.0833,
#   'Lng': -70.4333,
#   'Max Temp': 10.82,
#   'Humidity': 46,
#   'Cloudiness': 26,
#   'Wind Speed': 3.93,
#   'Country': 'PE',
#   'Date': -18000},
#  {'City': 'charleston',
#   'Lat': 32.7766,
#   'Lng': -79.9309,
#   'Max Temp': 28.9,
#   'Humidity': 67,
#   'Cloudiness': 0,
#   'Wind Speed': 5.66,
#   'Country': 'US',
#   'Date': -18000},
#  {'City': 'krasnyy chikoy',
#   'Lat': 50.3643,
#   'Lng': 108.7512,
#   'Max Temp': -7.08,
#   'Humidity': 92,
#   'Cloudiness': 20,
#   'Wind Speed': 1.39,
#   'Country': 'RU',
#   'Date': 32400},
#  {'City': 'goundam',
#   'Lat': 16.4145,
#   'Lng': -3.6708,
#   'Max Temp': 34.69,
#   'Humidity': 11,
#   'Cloudiness': 6,
#   'Wind Speed': 3.24,
#   'Country': 'ML',
#   'Date': 0},
#  {'City': 'burnie',
#   'Lat': -41.0667,
#   'Lng': 145.9167,
#   'Max Temp': 11.64,
#   'Humidity': 95,
#   'Cloudiness': 4,
#   'Wind Speed': 1.86,
#   'Country': 'AU',
#   'Date': 39600},
#  {'City': 'kavieng',
#   'Lat': -2.5744,
#   'Lng': 150.7967,
#   'Max Temp': 28.01,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 2.58,
#   'Country': 'PG',
#   'Date': 36000},
#  {'City': 'georgetown',
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Max Temp': 27.35,
#   'Humidity': 91,
#   'Cloudiness': 20,
#   'Wind Speed': 1.54,
#   'Country': 'MY',
#   'Date': 28800},
#  {'City': 'valparaiso',
#   'Lat': -33.0393,
#   'Lng': -71.6273,
#   'Max Temp': 21.13,
#   'Humidity': 79,
#   'Cloudiness': 75,
#   'Wind Speed': 5.14,
#   'Country': 'CL',
#   'Date': -10800},
#  {'City': 'qui nhon',
#   'Lat': 13.7667,
#   'Lng': 109.2333,
#   'Max Temp': 23.56,
#   'Humidity': 89,
#   'Cloudiness': 44,
#   'Wind Speed': 4.83,
#   'Country': 'VN',
#   'Date': 25200},
#  {'City': 'port elizabeth',
#   'Lat': -33.918,
#   'Lng': 25.5701,
#   'Max Temp': 22.28,
#   'Humidity': 83,
#   'Cloudiness': 20,
#   'Wind Speed': 8.23,
#   'Country': 'ZA',
#   'Date': 7200},
#  {'City': 'vikulovo',
#   'Lat': 56.8167,
#   'Lng': 70.6107,
#   'Max Temp': -4.29,
#   'Humidity': 91,
#   'Cloudiness': 93,
#   'Wind Speed': 3.89,
#   'Country': 'RU',
#   'Date': 18000},
#  {'City': 'ribeira grande',
#   'Lat': 38.5167,
#   'Lng': -28.7,
#   'Max Temp': 20.22,
#   'Humidity': 73,
#   'Cloudiness': 40,
#   'Wind Speed': 6.69,
#   'Country': 'PT',
#   'Date': -3600},
#  {'City': 'tiksi',
#   'Lat': 71.6872,
#   'Lng': 128.8694,
#   'Max Temp': -16.57,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 10.79,
#   'Country': 'RU',
#   'Date': 32400},
#  {'City': 'tsumeb',
#   'Lat': -19.2333,
#   'Lng': 17.7167,
#   'Max Temp': 26.19,
#   'Humidity': 36,
#   'Cloudiness': 95,
#   'Wind Speed': 1.99,
#   'Country': 'NA',
#   'Date': 7200},
#  {'City': 'san-pedro',
#   'Lat': 4.7485,
#   'Lng': -6.6363,
#   'Max Temp': 27,
#   'Humidity': 79,
#   'Cloudiness': 94,
#   'Wind Speed': 2.5,
#   'Country': 'CI',
#   'Date': 0},
#  {'City': 'broken hill',
#   'Lat': -31.95,
#   'Lng': 141.4333,
#   'Max Temp': 17.28,
#   'Humidity': 59,
#   'Cloudiness': 52,
#   'Wind Speed': 3.52,
#   'Country': 'AU',
#   'Date': 37800},
#  {'City': 'kuusamo',
#   'Lat': 65.9667,
#   'Lng': 29.1833,
#   'Max Temp': -0.98,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 3.09,
#   'Country': 'FI',
#   'Date': 7200},
#  {'City': 'hithadhoo',
#   'Lat': -0.6,
#   'Lng': 73.0833,
#   'Max Temp': 27.44,
#   'Humidity': 75,
#   'Cloudiness': 99,
#   'Wind Speed': 3.58,
#   'Country': 'MV',
#   'Date': 18000},
#  {'City': 'qandala',
#   'Lat': 11.472,
#   'Lng': 49.8728,
#   'Max Temp': 26.57,
#   'Humidity': 79,
#   'Cloudiness': 11,
#   'Wind Speed': 1.95,
#   'Country': 'SO',
#   'Date': 10800},
#  {'City': 'aklavik',
#   'Lat': 68.2191,
#   'Lng': -135.0107,
#   'Max Temp': -18.22,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 2.26,
#   'Country': 'CA',
#   'Date': -25200},
#  {'City': 'xiangfan',
#   'Lat': 32.0422,
#   'Lng': 112.1448,
#   'Max Temp': 16.35,
#   'Humidity': 59,
#   'Cloudiness': 0,
#   'Wind Speed': 1.81,
#   'Country': 'CN',
#   'Date': 28800},
#  {'City': 'calama',
#   'Lat': -22.4667,
#   'Lng': -68.9333,
#   'Max Temp': 24.27,
#   'Humidity': 9,
#   'Cloudiness': 0,
#   'Wind Speed': 9.26,
#   'Country': 'CL',
#   'Date': -10800},
#  {'City': 'saint george',
#   'Lat': 37.1041,
#   'Lng': -113.5841,
#   'Max Temp': 11.55,
#   'Humidity': 46,
#   'Cloudiness': 0,
#   'Wind Speed': 0.89,
#   'Country': 'US',
#   'Date': -25200},
#  {'City': 'chilca',
#   'Lat': -12.5211,
#   'Lng': -76.7372,
#   'Max Temp': 17.98,
#   'Humidity': 74,
#   'Cloudiness': 83,
#   'Wind Speed': 3.22,
#   'Country': 'PE',
#   'Date': -18000},
#  {'City': 'asau',
#   'Lat': 46.4333,
#   'Lng': 26.4,
#   'Max Temp': 11.51,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 1.71,
#   'Country': 'RO',
#   'Date': 7200},
#  {'City': 'outjo',
#   'Lat': -20.1167,
#   'Lng': 16.15,
#   'Max Temp': 19.9,
#   'Humidity': 60,
#   'Cloudiness': 80,
#   'Wind Speed': 10.07,
#   'Country': 'NA',
#   'Date': 7200},
#  {'City': 'ust-nera',
#   'Lat': 64.5667,
#   'Lng': 143.2,
#   'Max Temp': -23.05,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 1.4,
#   'Country': 'RU',
#   'Date': 36000},
#  {'City': 'kupang',
#   'Lat': -10.1667,
#   'Lng': 123.5833,
#   'Max Temp': 26.8,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 2.29,
#   'Country': 'ID',
#   'Date': 28800},
#  {'City': 'kamenka',
#   'Lat': 51.3223,
#   'Lng': 42.7678,
#   'Max Temp': 1.68,
#   'Humidity': 67,
#   'Cloudiness': 85,
#   'Wind Speed': 0.57,
#   'Country': 'RU',
#   'Date': 10800},
#  {'City': 'ouallam',
#   'Lat': 14.3188,
#   'Lng': 2.0866,
#   'Max Temp': 31.96,
#   'Humidity': 9,
#   'Cloudiness': 3,
#   'Wind Speed': 4.88,
#   'Country': 'NE',
#   'Date': 3600},
#  {'City': 'guerrero negro',
#   'Lat': 27.9769,
#   'Lng': -114.0611,
#   'Max Temp': 20.14,
#   'Humidity': 61,
#   'Cloudiness': 0,
#   'Wind Speed': 4.05,
#   'Country': 'MX',
#   'Date': -25200},
#  {'City': 'bathsheba',
#   'Lat': 13.2167,
#   'Lng': -59.5167,
#   'Max Temp': 29.34,
#   'Humidity': 79,
#   'Cloudiness': 40,
#   'Wind Speed': 6.69,
#   'Country': 'BB',
#   'Date': -14400},
#  {'City': 'praia',
#   'Lat': 14.9215,
#   'Lng': -23.5087,
#   'Max Temp': 31.3,
#   'Humidity': 45,
#   'Cloudiness': 0,
#   'Wind Speed': 6.17,
#   'Country': 'CV',
#   'Date': -3600},
#  {'City': 'markova',
#   'Lat': 48.6758,
#   'Lng': 24.4138,
#   'Max Temp': 8.15,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 1.02,
#   'Country': 'UA',
#   'Date': 7200},
#  {'City': 'alugan',
#   'Lat': 12.2188,
#   'Lng': 125.4808,
#   'Max Temp': 27.2,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 2.77,
#   'Country': 'PH',
#   'Date': 28800},
#  {'City': 'la rioja',
#   'Lat': 42.25,
#   'Lng': -2.5,
#   'Max Temp': 11.88,
#   'Humidity': 59,
#   'Cloudiness': 100,
#   'Wind Speed': 0.68,
#   'Country': 'ES',
#   'Date': 3600},
#  {'City': 'nara',
#   'Lat': 34.6851,
#   'Lng': 135.8049,
#   'Max Temp': 10.39,
#   'Humidity': 57,
#   'Cloudiness': 100,
#   'Wind Speed': 0.77,
#   'Country': 'JP',
#   'Date': 32400},
#  {'City': 'jalpan',
#   'Lat': 21.2333,
#   'Lng': -99.4833,
#   'Max Temp': 28.41,
#   'Humidity': 51,
#   'Cloudiness': 0,
#   'Wind Speed': 2.15,
#   'Country': 'MX',
#   'Date': -21600},
#  {'City': 'codrington',
#   'Lat': -38.2667,
#   'Lng': 141.9667,
#   'Max Temp': 11.51,
#   'Humidity': 85,
#   'Cloudiness': 3,
#   'Wind Speed': 3.01,
#   'Country': 'AU',
#   'Date': 39600},
#  {'City': 'longyearbyen',
#   'Lat': 78.2186,
#   'Lng': 15.6401,
#   'Max Temp': 0.91,
#   'Humidity': 75,
#   'Cloudiness': 40,
#   'Wind Speed': 7.2,
#   'Country': 'SJ',
#   'Date': 3600},
#  {'City': 'ilam',
#   'Lat': 26.9167,
#   'Lng': 87.9167,
#   'Max Temp': 14.47,
#   'Humidity': 87,
#   'Cloudiness': 31,
#   'Wind Speed': 1.98,
#   'Country': 'NP',
#   'Date': 20700},
#  {'City': 'biak',
#   'Lat': -0.9131,
#   'Lng': 122.8766,
#   'Max Temp': 25.14,
#   'Humidity': 81,
#   'Cloudiness': 93,
#   'Wind Speed': 2.37,
#   'Country': 'ID',
#   'Date': 28800},
#  {'City': 'tasiilaq',
#   'Lat': 65.6145,
#   'Lng': -37.6368,
#   'Max Temp': -2.91,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 1.55,
#   'Country': 'GL',
#   'Date': -10800},
#  {'City': 'lebu',
#   'Lat': -37.6167,
#   'Lng': -73.65,
#   'Max Temp': 14.81,
#   'Humidity': 68,
#   'Cloudiness': 20,
#   'Wind Speed': 5.92,
#   'Country': 'CL',
#   'Date': -10800},
#  {'City': 'tucuma',
#   'Lat': -0.1833,
#   'Lng': -50.05,
#   'Max Temp': 29.32,
#   'Humidity': 69,
#   'Cloudiness': 62,
#   'Wind Speed': 1.42,
#   'Country': 'BR',
#   'Date': -10800},
#  {'City': 'namatanai',
#   'Lat': -3.6667,
#   'Lng': 152.4333,
#   'Max Temp': 26.3,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 1.41,
#   'Country': 'PG',
#   'Date': 36000},
#  {'City': 'saldanha',
#   'Lat': -33.0117,
#   'Lng': 17.9442,
#   'Max Temp': 22.03,
#   'Humidity': 90,
#   'Cloudiness': 77,
#   'Wind Speed': 5.9,
#   'Country': 'ZA',
#   'Date': 7200},
#  {'City': 'muros',
#   'Lat': 42.7762,
#   'Lng': -9.0603,
#   'Max Temp': 17.27,
#   'Humidity': 82,
#   'Cloudiness': 20,
#   'Wind Speed': 6.3,
#   'Country': 'ES',
#   'Date': 3600},
#  {'City': 'inuvik',
#   'Lat': 68.3499,
#   'Lng': -133.7218,
#   'Max Temp': -12.52,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 3.09,
#   'Country': 'CA',
#   'Date': -25200},
#  {'City': 'xiaolingwei',
#   'Lat': 32.0333,
#   'Lng': 118.85,
#   'Max Temp': 8.99,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 2.48,
#   'Country': 'CN',
#   'Date': 28800},
#  {'City': 'senneterre',
#   'Lat': 48.3835,
#   'Lng': -77.2328,
#   'Max Temp': 9.59,
#   'Humidity': 74,
#   'Cloudiness': 98,
#   'Wind Speed': 6.16,
#   'Country': 'CA',
#   'Date': -18000},
#  {'City': 'athabasca',
#   'Lat': 54.7169,
#   'Lng': -113.2854,
#   'Max Temp': -12.5,
#   'Humidity': 70,
#   'Cloudiness': 100,
#   'Wind Speed': 5.14,
#   'Country': 'CA',
#   'Date': -25200},
#  {'City': 'saskylakh',
#   'Lat': 71.9167,
#   'Lng': 114.0833,
#   'Max Temp': -31.32,
#   'Humidity': 100,
#   'Cloudiness': 39,
#   'Wind Speed': 1.52,
#   'Country': 'RU',
#   'Date': 32400},
#  {'City': 'alegrete',
#   'Lat': -29.7831,
#   'Lng': -55.7919,
#   'Max Temp': 25.77,
#   'Humidity': 38,
#   'Cloudiness': 0,
#   'Wind Speed': 7.33,
#   'Country': 'BR',
#   'Date': -10800},
#  {'City': 'diego de almagro',
#   'Lat': -26.3667,
#   'Lng': -70.05,
#   'Max Temp': 27.99,
#   'Humidity': 16,
#   'Cloudiness': 0,
#   'Wind Speed': 5.72,
#   'Country': 'CL',
#   'Date': -10800},
#  {'City': 'orotukan',
#   'Lat': 62.2667,
#   'Lng': 151.7,
#   'Max Temp': -18.05,
#   'Humidity': 96,
#   'Cloudiness': 86,
#   'Wind Speed': 2.61,
#   'Country': 'RU',
#   'Date': 39600},
#  {'City': 'narsaq',
#   'Lat': 60.9167,
#   'Lng': -46.05,
#   'Max Temp': 3.12,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 1,
#   'Country': 'GL',
#   'Date': -10800},
#  {'City': 'souillac',
#   'Lat': -20.5167,
#   'Lng': 57.5167,
#   'Max Temp': 24.21,
#   'Humidity': 73,
#   'Cloudiness': 40,
#   'Wind Speed': 2.57,
#   'Country': 'MU',
#   'Date': 14400},
#  {'City': 'miri',
#   'Lat': 4.4148,
#   'Lng': 114.0089,
#   'Max Temp': 26.08,
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 1.03,
#   'Country': 'MY',
#   'Date': 28800},
#  {'City': 'nikolskoye',
#   'Lat': 59.7035,
#   'Lng': 30.7861,
#   'Max Temp': 1.94,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 3.31,
#   'Country': 'RU',
#   'Date': 10800},
#  {'City': 'cedar city',
#   'Lat': 37.6775,
#   'Lng': -113.0619,
#   'Max Temp': 6.33,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 1.54,
#   'Country': 'US',
#   'Date': -25200},
#  {'City': 'richards bay',
#   'Lat': -28.783,
#   'Lng': 32.0377,
#   'Max Temp': 20.82,
#   'Humidity': 78,
#   'Cloudiness': 11,
#   'Wind Speed': 2.6,
#   'Country': 'ZA',
#   'Date': 7200},
#  {'City': 'sanford',
#   'Lat': 28.8006,
#   'Lng': -81.2731,
#   'Max Temp': 30.62,
#   'Humidity': 74,
#   'Cloudiness': 40,
#   'Wind Speed': 5.14,
#   'Country': 'US',
#   'Date': -18000},
#  {'City': 'wakkanai',
#   'Lat': 45.4094,
#   'Lng': 141.6739,
#   'Max Temp': 6,
#   'Humidity': 52,
#   'Cloudiness': 84,
#   'Wind Speed': 7.54,
#   'Country': 'JP',
#   'Date': 32400},
#  {'City': 'misratah',
#   'Lat': 32.3754,
#   'Lng': 15.0925,
#   'Max Temp': 21.53,
#   'Humidity': 51,
#   'Cloudiness': 41,
#   'Wind Speed': 9.9,
#   'Country': 'LY',
#   'Date': 7200},
#  {'City': 'hovd',
#   'Lat': 48.0056,
#   'Lng': 91.6419,
#   'Max Temp': -0.86,
#   'Humidity': 65,
#   'Cloudiness': 100,
#   'Wind Speed': 1.11,
#   'Country': 'MN',
#   'Date': 25200},
#  {'City': 'pathein',
#   'Lat': 16.7833,
#   'Lng': 94.7333,
#   'Max Temp': 23.19,
#   'Humidity': 83,
#   'Cloudiness': 0,
#   'Wind Speed': 1.86,
#   'Country': 'MM',
#   'Date': 23400},
#  {'City': 'pitimbu',
#   'Lat': -7.4706,
#   'Lng': -34.8086,
#   'Max Temp': 29.33,
#   'Humidity': 70,
#   'Cloudiness': 76,
#   'Wind Speed': 5.23,
#   'Country': 'BR',
#   'Date': -10800},
#  {'City': 'yerbogachen',
#   'Lat': 61.2767,
#   'Lng': 108.0108,
#   'Max Temp': -8.5,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 2.88,
#   'Country': 'RU',
#   'Date': 28800},
#  {'City': 'auki',
#   'Lat': -8.7676,
#   'Lng': 160.7034,
#   'Max Temp': 25.29,
#   'Humidity': 86,
#   'Cloudiness': 71,
#   'Wind Speed': 1.21,
#   'Country': 'SB',
#   'Date': 39600},
#  {'City': 'half moon bay',
#   'Lat': 37.4636,
#   'Lng': -122.4286,
#   'Max Temp': 14.38,
#   'Humidity': 76,
#   'Cloudiness': 0,
#   'Wind Speed': 3.6,
#   'Country': 'US',
#   'Date': -28800},
#  {'City': 'vao',
#   'Lat': -22.6667,
#   'Lng': 167.4833,
#   'Max Temp': 23.71,
#   'Humidity': 85,
#   'Cloudiness': 40,
#   'Wind Speed': 7.69,
#   'Country': 'NC',
#   'Date': 39600},
#  {'City': 'flin flon',
#   'Lat': 54.7682,
#   'Lng': -101.865,
#   'Max Temp': -4.09,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 9.26,
#   'Country': 'CA',
#   'Date': -21600},
#  {'City': 'gravdal',
#   'Lat': 68.1214,
#   'Lng': 13.5031,
#   'Max Temp': 5.94,
#   'Humidity': 81,
#   'Cloudiness': 75,
#   'Wind Speed': 6.17,
#   'Country': 'NO',
#   'Date': 3600},
#  {'City': 'svetlogorsk',
#   'Lat': 52.6333,
#   'Lng': 29.7333,
#   'Max Temp': 5.24,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 5.08,
#   'Country': 'BY',
#   'Date': 10800},
#  {'City': 'tilichiki',
#   'Lat': 60.4667,
#   'Lng': 166.1,
#   'Max Temp': -8.29,
#   'Humidity': 95,
#   'Cloudiness': 54,
#   'Wind Speed': 3.06,
#   'Country': 'RU',
#   'Date': 43200},
#  {'City': 'talara',
#   'Lat': -4.5772,
#   'Lng': -81.2719,
#   'Max Temp': 22.42,
#   'Humidity': 64,
#   'Cloudiness': 0,
#   'Wind Speed': 6.69,
#   'Country': 'PE',
#   'Date': -18000},
#  {'City': 'karratha',
#   'Lat': -20.7377,
#   'Lng': 116.8463,
#   'Max Temp': 22.29,
#   'Humidity': 61,
#   'Cloudiness': 51,
#   'Wind Speed': 8.16,
#   'Country': 'AU',
#   'Date': 28800},
#  {'City': 'cockburn town',
#   'Lat': 21.4612,
#   'Lng': -71.1419,
#   'Max Temp': 24.98,
#   'Humidity': 73,
#   'Cloudiness': 40,
#   'Wind Speed': 5.66,
#   'Country': 'TC',
#   'Date': -18000},
#  {'City': 'svetlyy',
#   'Lat': 54.675,
#   'Lng': 20.1347,
#   'Max Temp': 7.03,
#   'Humidity': 78,
#   'Cloudiness': 17,
#   'Wind Speed': 6.24,
#   'Country': 'RU',
#   'Date': 7200},
#  {'City': 'mildura',
#   'Lat': -34.2,
#   'Lng': 142.15,
#   'Max Temp': 16.8,
#   'Humidity': 72,
#   'Cloudiness': 59,
#   'Wind Speed': 3.53,
#   'Country': 'AU',
#   'Date': 39600},
#  {'City': 'tripoli',
#   'Lat': 32.8752,
#   'Lng': 13.1875,
#   'Max Temp': 20.95,
#   'Humidity': 57,
#   'Cloudiness': 55,
#   'Wind Speed': 8.77,
#   'Country': 'LY',
#   'Date': 7200},
#  {'City': 'kijang',
#   'Lat': 35.2442,
#   'Lng': 129.2139,
#   'Max Temp': 6.85,
#   'Humidity': 46,
#   'Cloudiness': 62,
#   'Wind Speed': 1.83,
#   'Country': 'KR',
#   'Date': 32400},
#  {'City': 'naryan-mar',
#   'Lat': 67.6713,
#   'Lng': 53.087,
#   'Max Temp': 0.6,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 4.77,
#   'Country': 'RU',
#   'Date': 10800},
#  {'City': 'middle island',
#   'Lat': 40.8843,
#   'Lng': -72.9373,
#   'Max Temp': 23.55,
#   'Humidity': 79,
#   'Cloudiness': 0,
#   'Wind Speed': 6.69,
#   'Country': 'US',
#   'Date': -18000},
#  {'City': 'caconda',
#   'Lat': -13.7333,
#   'Lng': 15.0667,
#   'Max Temp': 22.81,
#   'Humidity': 45,
#   'Cloudiness': 30,
#   'Wind Speed': 3.2,
#   'Country': 'AO',
#   'Date': 3600},
#  {'City': 'pitea',
#   'Lat': 65.3172,
#   'Lng': 21.4794,
#   'Max Temp': 4.05,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 1.47,
#   'Country': 'SE',
#   'Date': 3600},
#  {'City': 'nabire',
#   'Lat': -3.3667,
#   'Lng': 135.4833,
#   'Max Temp': 23.97,
#   'Humidity': 92,
#   'Cloudiness': 94,
#   'Wind Speed': 1.49,
#   'Country': 'ID',
#   'Date': 32400},
#  {'City': 'ugoofaaru',
#   'Lat': 5.6667,
#   'Lng': 73,
#   'Max Temp': 27.54,
#   'Humidity': 72,
#   'Cloudiness': 95,
#   'Wind Speed': 2.71,
#   'Country': 'MV',
#   'Date': 18000},
#  {'City': 'ilulissat',
#   'Lat': 69.2167,
#   'Lng': -51.1,
#   'Max Temp': -17.16,
#   'Humidity': 96,
#   'Cloudiness': 55,
#   'Wind Speed': 2.69,
#   'Country': 'GL',
#   'Date': -10800},
#  {'City': 'ozernovskiy',
#   'Lat': 51.5,
#   'Lng': 156.5167,
#   'Max Temp': 2.36,
#   'Humidity': 67,
#   'Cloudiness': 100,
#   'Wind Speed': 4.13,
#   'Country': 'RU',
#   'Date': 43200},
#  {'City': 'olafsvik',
#   'Lat': 64.8945,
#   'Lng': -23.7142,
#   'Max Temp': 5.75,
#   'Humidity': 71,
#   'Cloudiness': 78,
#   'Wind Speed': 4.45,
#   'Country': 'IS',
#   'Date': 0},
#  {'City': 'tessalit',
#   'Lat': 20.1986,
#   'Lng': 1.0114,
#   'Max Temp': 29.39,
#   'Humidity': 11,
#   'Cloudiness': 0,
#   'Wind Speed': 3.79,
#   'Country': 'ML',
#   'Date': 0},
#  {'City': 'corinto',
#   'Lat': 37.9407,
#   'Lng': 22.9573,
#   'Max Temp': 15.5,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 1.84,
#   'Country': 'GR',
#   'Date': 7200},
#  {'City': 'poum',
#   'Lat': -20.2333,
#   'Lng': 164.0167,
#   'Max Temp': 25.75,
#   'Humidity': 77,
#   'Cloudiness': 0,
#   'Wind Speed': 2.6,
#   'Country': 'NC',
#   'Date': 39600},
#  {'City': 'melchor de mencos',
#   'Lat': 17.0686,
#   'Lng': -89.1522,
#   'Max Temp': 29,
#   'Humidity': 74,
#   'Cloudiness': 0,
#   'Wind Speed': 2.06,
#   'Country': 'GT',
#   'Date': -21600},
#  {'City': 'mahibadhoo',
#   'Lat': 3.7833,
#   'Lng': 72.9667,
#   'Max Temp': 27.69,
#   'Humidity': 76,
#   'Cloudiness': 61,
#   'Wind Speed': 5.1,
#   'Country': 'MV',
#   'Date': 18000},
#  {'City': 'pisco',
#   'Lat': -13.7,
#   'Lng': -76.2167,
#   'Max Temp': 20.57,
#   'Humidity': 72,
#   'Cloudiness': 0,
#   'Wind Speed': 4.12,
#   'Country': 'PE',
#   'Date': -18000},
#  {'City': 'finschhafen',
#   'Lat': -6.6024,
#   'Lng': 147.8681,
#   'Max Temp': 26.53,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 1.98,
#   'Country': 'PG',
#   'Date': 36000},
#  {'City': 'turan',
#   'Lat': 16.0678,
#   'Lng': 108.2208,
#   'Max Temp': 23.99,
#   'Humidity': 78,
#   'Cloudiness': 20,
#   'Wind Speed': 0.51,
#   'Country': 'VN',
#   'Date': 25200},
#  {'City': 'yar-sale',
#   'Lat': 66.8333,
#   'Lng': 70.8333,
#   'Max Temp': -4.02,
#   'Humidity': 96,
#   'Cloudiness': 94,
#   'Wind Speed': 3.11,
#   'Country': 'RU',
#   'Date': 18000},
#  {'City': 'hasaki',
#   'Lat': 35.7333,
#   'Lng': 140.8333,
#   'Max Temp': 7.22,
#   'Humidity': 54,
#   'Cloudiness': 89,
#   'Wind Speed': 3.43,
#   'Country': 'JP',
#   'Date': 32400},
#  {'City': 'meadow lake',
#   'Lat': 34.8014,
#   'Lng': -106.5436,
#   'Max Temp': 16.78,
#   'Humidity': 42,
#   'Cloudiness': 8,
#   'Wind Speed': 2.02,
#   'Country': 'US',
#   'Date': -25200},
#  {'City': 'fortuna',
#   'Lat': 40.5982,
#   'Lng': -124.1573,
#   'Max Temp': 9.81,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 6.69,
#   'Country': 'US',
#   'Date': -28800},
#  {'City': 'suwalki',
#   'Lat': 54.1118,
#   'Lng': 22.9309,
#   'Max Temp': 5.04,
#   'Humidity': 86,
#   'Cloudiness': 6,
#   'Wind Speed': 2.7,
#   'Country': 'PL',
#   'Date': 3600},
#  {'City': 'lusambo',
#   'Lat': -4.9667,
#   'Lng': 23.45,
#   'Max Temp': 21.7,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 0.45,
#   'Country': 'CD',
#   'Date': 7200},
#  {'City': 'ko samui',
#   'Lat': 9.5357,
#   'Lng': 99.9357,
#   'Max Temp': 26.43,
#   'Humidity': 82,
#   'Cloudiness': 99,
#   'Wind Speed': 6.02,
#   'Country': 'TH',
#   'Date': 25200},
#  {'City': 'sorland',
#   'Lat': 67.667,
#   'Lng': 12.6934,
#   'Max Temp': 6.92,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 10.35,
#   'Country': 'NO',
#   'Date': 3600},
#  {'City': 'husavik',
#   'Lat': 66.0449,
#   'Lng': -17.3389,
#   'Max Temp': 3.01,
#   'Humidity': 88,
#   'Cloudiness': 64,
#   'Wind Speed': 4.25,
#   'Country': 'IS',
#   'Date': 0},
#  {'City': 'mbulu',
#   'Lat': -3.85,
#   'Lng': 35.5333,
#   'Max Temp': 21.54,
#   'Humidity': 42,
#   'Cloudiness': 85,
#   'Wind Speed': 4.89,
#   'Country': 'TZ',
#   'Date': 10800},
#  {'City': 'dingle',
#   'Lat': 10.9995,
#   'Lng': 122.6711,
#   'Max Temp': 24.42,
#   'Humidity': 94,
#   'Cloudiness': 74,
#   'Wind Speed': 2.72,
#   'Country': 'PH',
#   'Date': 28800},
#  {'City': 'nyurba',
#   'Lat': 63.2842,
#   'Lng': 118.3319,
#   'Max Temp': -27.79,
#   'Humidity': 100,
#   'Cloudiness': 21,
#   'Wind Speed': 0.3,
#   'Country': 'RU',
#   'Date': 32400},
#  {'City': 'belaya gora',
#   'Lat': 68.5333,
#   'Lng': 146.4167,
#   'Max Temp': -15.81,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 6.37,
#   'Country': 'RU',
#   'Date': 39600},
#  {'City': 'elko',
#   'Lat': 41.0002,
#   'Lng': -115.5012,
#   'Max Temp': 3.19,
#   'Humidity': 83,
#   'Cloudiness': 72,
#   'Wind Speed': 3.58,
#   'Country': 'US',
#   'Date': -28800},
#  {'City': 'sitka',
#   'Lat': 57.0531,
#   'Lng': -135.33,
#   'Max Temp': -2.06,
#   'Humidity': 50,
#   'Cloudiness': 0,
#   'Wind Speed': 2.57,
#   'Country': 'US',
#   'Date': -32400},
#  {'City': 'opuwo',
#   'Lat': -18.0607,
#   'Lng': 13.84,
#   'Max Temp': 24.64,
#   'Humidity': 26,
#   'Cloudiness': 87,
#   'Wind Speed': 8.39,
#   'Country': 'NA',
#   'Date': 7200},
#  {'City': 'mastic beach',
#   'Lat': 40.7668,
#   'Lng': -72.8521,
#   'Max Temp': 23.63,
#   'Humidity': 84,
#   'Cloudiness': 0,
#   'Wind Speed': 5.14,
#   'Country': 'US',
#   'Date': -18000},
#  {'City': 'tenenkou',
#   'Lat': 14.4572,
#   'Lng': -4.9169,
#   'Max Temp': 35.26,
#   'Humidity': 14,
#   'Cloudiness': 0,
#   'Wind Speed': 6.08,
#   'Country': 'ML',
#   'Date': 0},
#  {'City': 'dyurtyuli',
#   'Lat': 55.4911,
#   'Lng': 54.8688,
#   'Max Temp': -2.3,
#   'Humidity': 90,
#   'Cloudiness': 80,
#   'Wind Speed': 3.65,
#   'Country': 'RU',
#   'Date': 18000},
#  {'City': 'lebane',
#   'Lat': 42.9239,
#   'Lng': 21.7375,
#   'Max Temp': 10.33,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 1.41,
#   'Country': 'RS',
#   'Date': 3600},
#  {'City': 'mizdah',
#   'Lat': 31.4451,
#   'Lng': 12.9801,
#   'Max Temp': 14.88,
#   'Humidity': 50,
#   'Cloudiness': 0,
#   'Wind Speed': 4.41,
#   'Country': 'LY',
#   'Date': 7200},
#  {'City': 'shahrud',
#   'Lat': 36.4182,
#   'Lng': 54.9763,
#   'Max Temp': 10.2,
#   'Humidity': 61,
#   'Cloudiness': 48,
#   'Wind Speed': 4.36,
#   'Country': 'IR',
#   'Date': 12600},
#  {'City': 'sivas',
#   'Lat': 39.7916,
#   'Lng': 37.0019,
#   'Max Temp': 6.35,
#   'Humidity': 52,
#   'Cloudiness': 20,
#   'Wind Speed': 1.54,
#   'Country': 'TR',
#   'Date': 10800},
#  {'City': 'saint-philippe',
#   'Lat': -21.3585,
#   'Lng': 55.7679,
#   'Max Temp': 23.77,
#   'Humidity': 82,
#   'Cloudiness': 64,
#   'Wind Speed': 2.93,
#   'Country': 'RE',
#   'Date': 14400},
#  {'City': 'maltahohe',
#   'Lat': -24.8333,
#   'Lng': 16.9833,
#   'Max Temp': 18.61,
#   'Humidity': 55,
#   'Cloudiness': 100,
#   'Wind Speed': 8.89,
#   'Country': 'NA',
#   'Date': 7200},
#  {'City': 'marica',
#   'Lat': -22.9194,
#   'Lng': -42.8186,
#   'Max Temp': 23.97,
#   'Humidity': 66,
#   'Cloudiness': 31,
#   'Wind Speed': 3.92,
#   'Country': 'BR',
#   'Date': -10800},
#  {'City': 'tirumullaivasal',
#   'Lat': 11.2333,
#   'Lng': 79.8333,
#   'Max Temp': 25.26,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 4.65,
#   'Country': 'IN',
#   'Date': 19800},
#  {'City': 'porto santo',
#   'Lat': 33.072,
#   'Lng': -16.3415,
#   'Max Temp': 21.21,
#   'Humidity': 73,
#   'Cloudiness': 20,
#   'Wind Speed': 3.09,
#   'Country': 'PT',
#   'Date': 0},
#  {'City': 'elmira',
#   'Lat': 42.0898,
#   'Lng': -76.8077,
#   'Max Temp': 24.18,
#   'Humidity': 72,
#   'Cloudiness': 40,
#   'Wind Speed': 6.69,
#   'Country': 'US',
#   'Date': -18000},
#  {'City': 'quatre cocos',
#   'Lat': -20.2078,
#   'Lng': 57.7625,
#   'Max Temp': 24.06,
#   'Humidity': 72,
#   'Cloudiness': 17,
#   'Wind Speed': 4.37,
#   'Country': 'MU',
#   'Date': 14400},
#  {'City': 'salalah',
#   'Lat': 17.0151,
#   'Lng': 54.0924,
# ...
#   'Country': 'CA',
#   'Date': -21600},
#  {'City': 'abu dhabi',
#   'Lat': 24.4667,
#   'Lng': 54.3667,
#   'Max Temp': 29.06,
#   'Humidity': 66,
#   'Cloudiness': 0,
#   'Wind Speed': 1.54,
#   'Country': 'AE',
#   'Date': 14400},
#  {'City': 'kawambwa',
#   'Lat': -9.7915,
#   'Lng': 29.0791,
#   'Max Temp': 18.88,
#   'Humidity': 88,
#   'Cloudiness': 77,
#   'Wind Speed': 1.21,
#   'Country': 'ZM',
#   'Date': 7200},
#  {'City': 'lyskovo',
#   'Lat': 56.0328,
#   'Lng': 45.0422,
#   'Max Temp': -1.34,
#   'Humidity': 79,
#   'Cloudiness': 28,
#   'Wind Speed': 2.46,
#   'Country': 'RU',
#   'Date': 10800},
#  {'City': 'oranjemund',
#   'Lat': -28.55,
#   'Lng': 16.4333,
#   'Max Temp': 17.24,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 4.24,
#   'Country': 'NA',
#   'Date': 7200},
#  {'City': 'cadillac',
#   'Lat': 44.2519,
#   'Lng': -85.4012,
#   'Max Temp': 9.95,
#   'Humidity': 66,
#   'Cloudiness': 0,
#   'Wind Speed': 6.69,
#   'Country': 'US',
#   'Date': -18000},
#  {'City': 'mersing',
#   'Lat': 2.4312,
#   'Lng': 103.8405,
#   'Max Temp': 23.95,
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 2.06,
#   'Country': 'MY',
#   'Date': 28800},
#  {'City': 'vilhena',
#   'Lat': -12.7406,
#   'Lng': -60.1458,
#   'Max Temp': 31.12,
#   'Humidity': 33,
#   'Cloudiness': 20,
#   'Wind Speed': 3.6,
#   'Country': 'BR',
#   'Date': -14400},
#  {'City': 'bonthe',
#   'Lat': 7.5264,
#   'Lng': -12.505,
#   'Max Temp': 28.41,
#   'Humidity': 69,
#   'Cloudiness': 50,
#   'Wind Speed': 2.97,
#   'Country': 'SL',
#   'Date': 0},
#  {'City': 'maniitsoq',
#   'Lat': 65.4167,
#   'Lng': -52.9,
#   'Max Temp': -6.08,
#   'Humidity': 56,
#   'Cloudiness': 1,
#   'Wind Speed': 2.64,
#   'Country': 'GL',
#   'Date': -10800},
#  {'City': 'burriana',
#   'Lat': 39.889,
#   'Lng': -0.085,
#   'Max Temp': 22.47,
#   'Humidity': 39,
#   'Cloudiness': 54,
#   'Wind Speed': 1.57,
#   'Country': 'ES',
#   'Date': 3600},
#  {'City': 'sabaudia',
#   'Lat': 41.3003,
#   'Lng': 13.0282,
#   'Max Temp': 18.04,
#   'Humidity': 80,
#   'Cloudiness': 0,
#   'Wind Speed': 1.02,
#   'Country': 'IT',
#   'Date': 3600},
#  {'City': 'aketi',
#   'Lat': 2.7388,
#   'Lng': 23.7833,
#   'Max Temp': 22.14,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 0.6,
#   'Country': 'CD',
#   'Date': 7200},
#  {'City': 'voh',
#   'Lat': -20.9667,
#   'Lng': 164.7,
#   'Max Temp': 23.22,
#   'Humidity': 89,
#   'Cloudiness': 0,
#   'Wind Speed': 1.72,
#   'Country': 'NC',
#   'Date': 39600},
#  {'City': 'san patricio',
#   'Lat': 28.017,
#   'Lng': -97.5169,
#   'Max Temp': 28.93,
#   'Humidity': 68,
#   'Cloudiness': 27,
#   'Wind Speed': 3.4,
#   'Country': 'US',
#   'Date': -21600},
#  {'City': 'los llanos de aridane',
#   'Lat': 28.6585,
#   'Lng': -17.9182,
#   'Max Temp': 21.74,
#   'Humidity': 76,
#   'Cloudiness': 75,
#   'Wind Speed': 3.6,
#   'Country': 'ES',
#   'Date': 0},
#  {'City': 'changji',
#   'Lat': 44.0167,
#   'Lng': 87.3167,
#   'Max Temp': 6.44,
#   'Humidity': 70,
#   'Cloudiness': 100,
#   'Wind Speed': 1,
#   'Country': 'CN',
#   'Date': 28800},
#  {'City': 'saint-joseph',
#   'Lat': -21.3667,
#   'Lng': 55.6167,
#   'Max Temp': 23.21,
#   'Humidity': 80,
#   'Cloudiness': 55,
#   'Wind Speed': 2.7,
#   'Country': 'RE',
#   'Date': 14400},
#  {'City': 'nantucket',
#   'Lat': 41.2835,
#   'Lng': -70.0995,
#   'Max Temp': 21.75,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 7.2,
#   'Country': 'US',
#   'Date': -18000},
#  {'City': 'sira',
#   'Lat': 13.7453,
#   'Lng': 76.9092,
#   'Max Temp': 21.1,
#   'Humidity': 86,
#   'Cloudiness': 88,
#   'Wind Speed': 3.52,
#   'Country': 'IN',
#   'Date': 19800},
#  {'City': 'hauterive',
#   'Lat': 46.0901,
#   'Lng': 3.4459,
#   'Max Temp': 15.42,
#   'Humidity': 62,
#   'Cloudiness': 83,
#   'Wind Speed': 3.17,
#   'Country': 'FR',
#   'Date': 3600},
#  {'City': 'rantepao',
#   'Lat': -2.9701,
#   'Lng': 119.8978,
#   'Max Temp': 19.89,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 0.65,
#   'Country': 'ID',
#   'Date': 28800},
#  {'City': 'hohoe',
#   'Lat': 7.1518,
#   'Lng': 0.4736,
#   'Max Temp': 27.91,
#   'Humidity': 70,
#   'Cloudiness': 60,
#   'Wind Speed': 1.03,
#   'Country': 'GH',
#   'Date': 0},
#  {'City': 'manadhoo',
#   'Lat': 5.7667,
#   'Lng': 73.3833,
#   'Max Temp': 27.42,
#   'Humidity': 71,
#   'Cloudiness': 96,
#   'Wind Speed': 2.07,
#   'Country': 'MV',
#   'Date': 18000},
#  {'City': 'mandalgovi',
#   'Lat': 45.7625,
#   'Lng': 106.2708,
#   'Max Temp': -2.3,
#   'Humidity': 47,
#   'Cloudiness': 1,
#   'Wind Speed': 2.83,
#   'Country': 'MN',
#   'Date': 28800},
#  {'City': 'jishou',
#   'Lat': 28.3167,
#   'Lng': 109.7167,
#   'Max Temp': 15.7,
#   'Humidity': 71,
#   'Cloudiness': 0,
#   'Wind Speed': 0.55,
#   'Country': 'CN',
#   'Date': 28800},
#  {'City': 'ilebo',
#   'Lat': -4.3167,
#   'Lng': 20.5833,
#   'Max Temp': 22.28,
#   'Humidity': 93,
#   'Cloudiness': 57,
#   'Wind Speed': 0.79,
#   'Country': 'CD',
#   'Date': 7200},
#  {'City': 'tulum',
#   'Lat': 20.2167,
#   'Lng': -87.4667,
#   'Max Temp': 29.64,
#   'Humidity': 49,
#   'Cloudiness': 5,
#   'Wind Speed': 1.8,
#   'Country': 'MX',
#   'Date': -18000},
#  {'City': 'havre',
#   'Lat': 49.5833,
#   'Lng': 0.3333,
#   'Max Temp': 12.87,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 6.17,
#   'Country': 'FR',
#   'Date': 3600},
#  {'City': 'antofagasta',
#   'Lat': -23.65,
#   'Lng': -70.4,
#   'Max Temp': 17.6,
#   'Humidity': 65,
#   'Cloudiness': 40,
#   'Wind Speed': 4.22,
#   'Country': 'CL',
#   'Date': -10800},
#  {'City': 'yangshe',
#   'Lat': 31.8899,
#   'Lng': 120.6052,
#   'Max Temp': 13.33,
#   'Humidity': 83,
#   'Cloudiness': 0,
#   'Wind Speed': 0.45,
#   'Country': 'CN',
#   'Date': 28800},
#  {'City': 'kalmunai',
#   'Lat': 7.4167,
#   'Lng': 81.8167,
#   'Max Temp': 25.48,
#   'Humidity': 77,
#   'Cloudiness': 99,
#   'Wind Speed': 2.68,
#   'Country': 'LK',
#   'Date': 19800},
#  {'City': 'matamoros',
#   'Lat': 25.5333,
#   'Lng': -103.25,
#   'Max Temp': 24.74,
#   'Humidity': 18,
#   'Cloudiness': 0,
#   'Wind Speed': 0.58,
#   'Country': 'MX',
#   'Date': -21600},
#  {'City': 'raudeberg',
#   'Lat': 61.9875,
#   'Lng': 5.1352,
#   'Max Temp': 6.64,
#   'Humidity': 35,
#   'Cloudiness': 99,
#   'Wind Speed': 4.75,
#   'Country': 'NO',
#   'Date': 3600},
#  {'City': 'mulchen',
#   'Lat': -37.7167,
#   'Lng': -72.2333,
#   'Max Temp': 27.42,
#   'Humidity': 23,
#   'Cloudiness': 34,
#   'Wind Speed': 1.74,
#   'Country': 'CL',
#   'Date': -10800},
#  {'City': 'innisfail',
#   'Lat': -17.5333,
#   'Lng': 146.0333,
#   'Max Temp': 23.27,
#   'Humidity': 82,
#   'Cloudiness': 57,
#   'Wind Speed': 2.11,
#   'Country': 'AU',
#   'Date': 36000},
#  {'City': 'coquimbo',
#   'Lat': -29.9533,
#   'Lng': -71.3436,
#   'Max Temp': 17.85,
#   'Humidity': 63,
#   'Cloudiness': 20,
#   'Wind Speed': 5.66,
#   'Country': 'CL',
#   'Date': -10800},
#  {'City': 'trujillo',
#   'Lat': -8.116,
#   'Lng': -79.03,
#   'Max Temp': 18.98,
#   'Humidity': 72,
#   'Cloudiness': 40,
#   'Wind Speed': 5.14,
#   'Country': 'PE',
#   'Date': -18000},
#  {'City': 'vila franca do campo',
#   'Lat': 37.7167,
#   'Lng': -25.4333,
#   'Max Temp': 20.66,
#   'Humidity': 71,
#   'Cloudiness': 29,
#   'Wind Speed': 3.73,
#   'Country': 'PT',
#   'Date': -3600},
#  {'City': 'gogrial',
#   'Lat': 8.5332,
#   'Lng': 28.1004,
#   'Max Temp': 27.57,
#   'Humidity': 37,
#   'Cloudiness': 89,
#   'Wind Speed': 2.13,
#   'Country': 'SS',
#   'Date': 7200},
#  {'City': 'sena madureira',
#   'Lat': -9.0656,
#   'Lng': -68.6569,
#   'Max Temp': 37.64,
#   'Humidity': 18,
#   'Cloudiness': 49,
#   'Wind Speed': 0.5,
#   'Country': 'BR',
#   'Date': -18000},
#  {'City': 'mobaye',
#   'Lat': 4.319,
#   'Lng': 21.1786,
#   'Max Temp': 22.99,
#   'Humidity': 91,
#   'Cloudiness': 82,
#   'Wind Speed': 1.44,
#   'Country': 'CF',
#   'Date': 3600},
#  {'City': 'vero beach',
#   'Lat': 27.6386,
#   'Lng': -80.3973,
#   'Max Temp': 30.59,
#   'Humidity': 76,
#   'Cloudiness': 40,
#   'Wind Speed': 7.2,
#   'Country': 'US',
#   'Date': -18000},
#  {'City': 'lichinga',
#   'Lat': -13.3128,
#   'Lng': 35.2406,
#   'Max Temp': 24.74,
#   'Humidity': 35,
#   'Cloudiness': 96,
#   'Wind Speed': 1.93,
#   'Country': 'MZ',
#   'Date': 7200},
#  {'City': 'doka',
#   'Lat': 13.5167,
#   'Lng': 35.7667,
#   'Max Temp': 29.04,
#   'Humidity': 25,
#   'Cloudiness': 4,
#   'Wind Speed': 2.51,
#   'Country': 'SD',
#   'Date': 7200},
#  {'City': 'constitucion',
#   'Lat': -35.3333,
#   'Lng': -72.4167,
#   'Max Temp': 17.4,
#   'Humidity': 65,
#   'Cloudiness': 52,
#   'Wind Speed': 5.46,
#   'Country': 'CL',
#   'Date': -10800},
#  {'City': 'greensburg',
#   'Lat': 40.3015,
#   'Lng': -79.5389,
#   'Max Temp': 25.14,
#   'Humidity': 56,
#   'Cloudiness': 0,
#   'Wind Speed': 5.14,
#   'Country': 'US',
#   'Date': -18000},
#  {'City': 'ust-maya',
#   'Lat': 60.4167,
#   'Lng': 134.5333,
#   'Max Temp': -18.35,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 1.06,
#   'Country': 'RU',
#   'Date': 32400},
#  {'City': 'bowen',
#   'Lat': -20.0167,
#   'Lng': 148.2333,
#   'Max Temp': 23.96,
#   'Humidity': 75,
#   'Cloudiness': 67,
#   'Wind Speed': 7.79,
#   'Country': 'AU',
#   'Date': 36000},
#  {'City': 'bambous virieux',
#   'Lat': -20.3428,
#   'Lng': 57.7575,
#   'Max Temp': 24.14,
#   'Humidity': 73,
#   'Cloudiness': 40,
#   'Wind Speed': 2.57,
#   'Country': 'MU',
#   'Date': 14400},
#  {'City': 'santa rosa',
#   'Lat': 14.3122,
#   'Lng': 121.1114,
#   'Max Temp': 27.28,
#   'Humidity': 82,
#   'Cloudiness': 86,
#   'Wind Speed': 2.7,
#   'Country': 'PH',
#   'Date': 28800},
#  {'City': 'jining',
#   'Lat': 35.405,
#   'Lng': 116.5814,
#   'Max Temp': 11.19,
#   'Humidity': 51,
#   'Cloudiness': 28,
#   'Wind Speed': 2.9,
#   'Country': 'CN',
#   'Date': 28800},
#  {'City': 'concepcion del uruguay',
#   'Lat': -32.4825,
#   'Lng': -58.2372,
#   'Max Temp': 25.7,
#   'Humidity': 42,
#   'Cloudiness': 2,
#   'Wind Speed': 2.68,
#   'Country': 'AR',
#   'Date': -10800},
#  {'City': 'ballina',
#   'Lat': -28.8667,
#   'Lng': 153.5667,
#   'Max Temp': 13.9,
#   'Humidity': 99,
#   'Cloudiness': 37,
#   'Wind Speed': 2.58,
#   'Country': 'AU',
#   'Date': 39600},
#  {'City': 'gasa',
#   'Lat': 31.5,
#   'Lng': 34.4667,
#   'Max Temp': 22.71,
#   'Humidity': 68,
#   'Cloudiness': 1,
#   'Wind Speed': 3.87,
#   'Country': 'PS',
#   'Date': 7200},
#  {'City': 'uniontown',
#   'Lat': 39.9001,
#   'Lng': -79.7164,
#   'Max Temp': 25.12,
#   'Humidity': 40,
#   'Cloudiness': 79,
#   'Wind Speed': 1.34,
#   'Country': 'US',
#   'Date': -18000},
#  {'City': 'charters towers',
#   'Lat': -20.1,
#   'Lng': 146.2667,
#   'Max Temp': 20.57,
#   'Humidity': 79,
#   'Cloudiness': 34,
#   'Wind Speed': 4.29,
#   'Country': 'AU',
#   'Date': 36000},
#  {'City': 'iyo',
#   'Lat': 33.7514,
#   'Lng': 132.7014,
#   'Max Temp': 12.81,
#   'Humidity': 74,
#   'Cloudiness': 91,
#   'Wind Speed': 1.77,
#   'Country': 'JP',
#   'Date': 32400},
#  {'City': 'taloqan',
#   'Lat': 36.7361,
#   'Lng': 69.5345,
#   'Max Temp': 14.03,
#   'Humidity': 60,
#   'Cloudiness': 67,
#   'Wind Speed': 1.38,
#   'Country': 'AF',
#   'Date': 16200},
#  {'City': 'ahome',
#   'Lat': 25.9167,
#   'Lng': -109.1833,
#   'Max Temp': 24.17,
#   'Humidity': 37,
#   'Cloudiness': 0,
#   'Wind Speed': 0.9,
#   'Country': 'MX',
#   'Date': -25200},
#  {'City': 'ladispoli',
#   'Lat': 41.9537,
#   'Lng': 12.0735,
#   'Max Temp': 19.06,
#   'Humidity': 61,
#   'Cloudiness': 7,
#   'Wind Speed': 4.54,
#   'Country': 'IT',
#   'Date': 3600},
#  {'City': 'akom',
#   'Lat': 2.6678,
#   'Lng': 12.7109,
#   'Max Temp': 23.26,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 1.07,
#   'Country': 'CM',
#   'Date': 3600},
#  {'City': 'romny',
#   'Lat': 50.751,
#   'Lng': 33.4747,
#   'Max Temp': 2.35,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 3.4,
#   'Country': 'UA',
#   'Date': 7200},
#  {'City': 'abnub',
#   'Lat': 27.2696,
#   'Lng': 31.1511,
#   'Max Temp': 24.12,
#   'Humidity': 29,
#   'Cloudiness': 2,
#   'Wind Speed': 3.35,
#   'Country': 'EG',
#   'Date': 7200},
#  {'City': 'ivanava',
#   'Lat': 52.1451,
#   'Lng': 25.5365,
#   'Max Temp': 8.48,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 0.17,
#   'Country': 'BY',
#   'Date': 10800},
#  {'City': 'takaka',
#   'Lat': -40.85,
#   'Lng': 172.8,
#   'Max Temp': 10.31,
#   'Humidity': 89,
#   'Cloudiness': 9,
#   'Wind Speed': 2.16,
#   'Country': 'NZ',
#   'Date': 46800},
#  {'City': 'morondava',
#   'Lat': -20.2833,
#   'Lng': 44.2833,
#   'Max Temp': 26.93,
#   'Humidity': 80,
#   'Cloudiness': 58,
#   'Wind Speed': 4.76,
#   'Country': 'MG',
#   'Date': 10800},
#  {'City': 'jinzhou',
#   'Lat': 41.1078,
#   'Lng': 121.1417,
#   'Max Temp': 8.44,
#   'Humidity': 64,
#   'Cloudiness': 90,
#   'Wind Speed': 1.73,
#   'Country': 'CN',
#   'Date': 28800},
#  {'City': 'wanning',
#   'Lat': 18.8003,
#   'Lng': 110.3967,
#   'Max Temp': 22.59,
#   'Humidity': 90,
#   'Cloudiness': 94,
#   'Wind Speed': 3.4,
#   'Country': 'CN',
#   'Date': 28800},
#  {'City': 'hanna',
#   'Lat': 51.6334,
#   'Lng': -111.9018,
#   'Max Temp': -12.3,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 2.24,
#   'Country': 'CA',
#   'Date': -25200},
#  {'City': 'the valley',
#   'Lat': 18.217,
#   'Lng': -63.0578,
#   'Max Temp': 29.34,
#   'Humidity': 79,
#   'Cloudiness': 20,
#   'Wind Speed': 8.23,
#   'Country': 'AI',
#   'Date': -14400},
#  {'City': 'katangli',
#   'Lat': 51.7102,
#   'Lng': 143.2326,
#   'Max Temp': -7.07,
#   'Humidity': 75,
#   'Cloudiness': 9,
#   'Wind Speed': 4.28,
#   'Country': 'RU',
#   'Date': 39600},
#  {'City': 'nome',
#   'Lat': 64.5011,
#   'Lng': -165.4064,
#   'Max Temp': 1.04,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 11.83,
#   'Country': 'US',
#   'Date': -32400},
#  {'City': 'comodoro rivadavia',
#   'Lat': -45.8667,
#   'Lng': -67.5,
#   'Max Temp': 24.92,
#   'Humidity': 23,
#   'Cloudiness': 0,
#   'Wind Speed': 8.23,
#   'Country': 'AR',
#   'Date': -10800},
#  {'City': 'ayorou',
#   'Lat': 14.7308,
#   'Lng': 0.9174,
#   'Max Temp': 32.66,
#   'Humidity': 10,
#   'Cloudiness': 1,
#   'Wind Speed': 3.68,
#   'Country': 'NE',
#   'Date': 3600},
#  {'City': 'ramhormoz',
#   'Lat': 31.28,
#   'Lng': 49.6035,
#   'Max Temp': 22.01,
#   'Humidity': 29,
#   'Cloudiness': 0,
#   'Wind Speed': 0.8,
#   'Country': 'IR',
#   'Date': 12600},
#  {'City': 'sambava',
#   'Lat': -14.2667,
#   'Lng': 50.1667,
#   'Max Temp': 23.37,
#   'Humidity': 86,
#   'Cloudiness': 20,
#   'Wind Speed': 2.87,
#   'Country': 'MG',
#   'Date': 10800},
#  {'City': 'majalengka',
#   'Lat': -6.8361,
#   'Lng': 108.2278,
#   'Max Temp': 24.51,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 1.36,
#   'Country': 'ID',
#   'Date': 25200},
#  {'City': 'vila velha',
#   'Lat': -20.3297,
#   'Lng': -40.2925,
#   'Max Temp': 24.97,
#   'Humidity': 65,
#   'Cloudiness': 20,
#   'Wind Speed': 7.72,
#   'Country': 'BR',
#   'Date': -10800},
#  {'City': 'iquique',
#   'Lat': -20.2208,
#   'Lng': -70.1431,
#   'Max Temp': 19.02,
#   'Humidity': 63,
#   'Cloudiness': 1,
#   'Wind Speed': 3.19,
#   'Country': 'CL',
#   'Date': -10800},
#  {'City': 'erzurum',
#   'Lat': 40,
#   'Lng': 41.5,
#   'Max Temp': 2.82,
#   'Humidity': 48,
#   'Cloudiness': 80,
#   'Wind Speed': 1.92,
#   'Country': 'TR',
#   'Date': 10800},
#  {'City': 'remscheid',
#   'Lat': 51.1833,
#   'Lng': 7.2,
#   'Max Temp': 9.61,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 5.14,
#   'Country': 'DE',
#   'Date': 3600},
#  {'City': 'berlevag',
#   'Lat': 70.8578,
#   'Lng': 29.0864,
#   'Max Temp': 3,
#   'Humidity': 75,
#   'Cloudiness': 20,
#   'Wind Speed': 3.6,
#   'Country': 'NO',
#   'Date': 3600},
#  {'City': 'kutum',
#   'Lat': 14.2,
#   'Lng': 24.6667,
#   'Max Temp': 25.5,
#   'Humidity': 20,
#   'Cloudiness': 13,
#   'Wind Speed': 2.89,
#   'Country': 'SD',
#   'Date': 7200},
#  {'City': 'raga',
#   'Lat': 8.4596,
#   'Lng': 25.678,
#   'Max Temp': 28.04,
#   'Humidity': 31,
#   'Cloudiness': 49,
#   'Wind Speed': 1.38,
#   'Country': 'SS',
#   'Date': 7200},
#  {'City': 'ouidah',
#   'Lat': 6.3631,
#   'Lng': 2.0851,
#   'Max Temp': 27.57,
#   'Humidity': 76,
#   'Cloudiness': 98,
#   'Wind Speed': 3.55,
#   'Country': 'BJ',
#   'Date': 3600},
#  {'City': 'ngunguru',
#   'Lat': -35.6167,
#   'Lng': 174.5,
#   'Max Temp': 15.49,
#   'Humidity': 71,
#   'Cloudiness': 99,
#   'Wind Speed': 7.28,
#   'Country': 'NZ',
#   'Date': 46800},
#  {'City': 'inhambane',
#   'Lat': -23.865,
#   'Lng': 35.3833,
#   'Max Temp': 25.32,
#   'Humidity': 85,
#   'Cloudiness': 56,
#   'Wind Speed': 3.54,
#   'Country': 'MZ',
#   'Date': 7200},
#  {'City': 'naze',
#   'Lat': 28.3667,
#   'Lng': 129.4833,
#   'Max Temp': 18.51,
#   'Humidity': 68,
#   'Cloudiness': 100,
#   'Wind Speed': 2.66,
#   'Country': 'JP',
#   'Date': 32400},
#  {'City': 'ocos',
#   'Lat': 14.5094,
#   'Lng': -92.1933,
#   'Max Temp': 27.81,
#   'Humidity': 73,
#   'Cloudiness': 33,
#   'Wind Speed': 1.94,
#   'Country': 'GT',
#   'Date': -21600},
#  {'City': 'djibo',
#   'Lat': 14.1022,
#   'Lng': -1.6306,
#   'Max Temp': 33.86,
#   'Humidity': 12,
#   'Cloudiness': 2,
#   'Wind Speed': 4.55,
#   'Country': 'BF',
#   'Date': 0},
#  {'City': 'la ronge',
#   'Lat': 55.1001,
#   'Lng': -105.2842,
#   'Max Temp': -7.86,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 7.2,
#   'Country': 'CA',
#   'Date': -21600}]

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame (city_data, columns = ['City','Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed','Country','Date'])
# Show Record Count
city_data_df.count()
# Out:
# City          578
# Lat           578
# Lng           578
# Max Temp      578
# Humidity      578
# Cloudiness    578
# Wind Speed    578
# Country       578
# Date          578
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  salinopolis  -0.6136  -47.3561     30.49        58          27        3.86
# 1      ternate   0.8000  127.4000     27.36        78         100        0.95
# 2       hobart -42.8794  147.3294     10.70        94          12        1.62
# 3       albany  42.6001  -73.9662     21.81        81         100        0.89
# 4  tsaratanana -16.7833   47.6500     27.97        47          66        2.31
#
#   Country   Date
# 0      BR -10800
# 1      ID  32400
# 2      AU  39600
# 3      US -18000
# 4      MG  10800

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        salinopolis  -0.6136  -47.3561     30.49        58          27
# 1            ternate   0.8000  127.4000     27.36        78         100
# 2             hobart -42.8794  147.3294     10.70        94          12
# 3             albany  42.6001  -73.9662     21.81        81         100
# 4        tsaratanana -16.7833   47.6500     27.97        47          66
#
#          Wind Speed Country   Date
# City_ID
# 0              3.86      BR -10800
# 1              0.95      ID  32400
# 2              1.62      AU  39600
# 3              0.89      US -18000
# 4              2.31      MG  10800

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df['Lat'],city_data_df['Max Temp'])

# Incorporate the other graph properties
plt.title("City Max Temperature vs Latitude")
plt.ylabel("Max Temperature (C)")
plt.xlabel("Latitude")
plt.grid(True)


# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df['Lat'],city_data_df['Humidity'])

# Incorporate the other graph properties
plt.title("City Max Temperature vs Humidity")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df['Lat'],city_data_df['Cloudiness'])

# Incorporate the other graph properties
plt.title("City Max Temperature vs Cloudiness")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)


# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df['Lat'],city_data_df['Wind Speed'])

# Incorporate the other graph properties
plt.title("City Max Temperature vs Wind Speed")
plt.ylabel("Wind Speed (m/s)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def estimate_coef(x, y):
    # number of observations/points
    n = np.size(x)
  
    # mean of x and y vector
    m_x = np.mean(x)
    m_y = np.mean(y)
  
    # calculating cross-deviation and deviation about x
    SS_xy = np.sum(y*x) - n*m_y*m_x
    SS_xx = np.sum(x*x) - n*m_x*m_x
  
    # calculating regression coefficients
    b_1 = SS_xy / SS_xx
    b_0 = m_y - b_1*m_x
    reg_line ='y = {}x + {}'.format(round(b_1, 2),round(b_0, 2))
    return (b_0, b_1,reg_line)

def plot_regression_line(x, y, b):
    # plotting the actual points as scatter plot
    plt.scatter(x, y, color = "b",
               marker = "o", s = 30)
  
    # predicted response vector
    y_pred = b[0] + b[1]*x
  
    # plotting the regression line
    plt.plot(x, y_pred, color = "g")

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df =pd.DataFrame (city_data_df[city_data_df['Lat']>= 0])
# Display sample data
northern_hemi_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1          ternate   0.8000  127.4000     27.36        78         100
# 3           albany  42.6001  -73.9662     21.81        81         100
# 6           dwarka  22.2394   68.9678     26.98        67          83
# 8           mehamn  71.0357   27.8492      2.97        65          75
# 9        jamestown  42.0970  -79.2353     21.68        69         100
#
#          Wind Speed Country   Date
# City_ID
# 1              0.95      ID  32400
# 3              0.89      US -18000
# 6              3.85      IN  19800
# 8              4.63      NO   3600
# 9              8.23      US -18000

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df =pd.DataFrame (city_data_df[city_data_df['Lat'] < 0])

# Display sample data
southern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0         salinopolis  -0.6136  -47.3561     30.49        58          27
# 2              hobart -42.8794  147.3294     10.70        94          12
# 4         tsaratanana -16.7833   47.6500     27.97        47          66
# 5        punta arenas -53.1500  -70.9167     13.06        67           0
# 7          bredasdorp -34.5322   20.0403     19.15        81          51
#
#          Wind Speed Country   Date
# City_ID
# 0              3.86      BR -10800
# 2              1.62      AU  39600
# 4              2.31      MG  10800
# 5              4.12      CL -10800
# 7              5.41      ZA   7200

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere

corr_matrix = np.corrcoef(northern_hemi_df['Lat'],northern_hemi_df['Max Temp'])
corr = corr_matrix[0,1]
R_sq = corr**2
print('The r-value is:',R_sq)

plt.scatter(northern_hemi_df['Lat'],northern_hemi_df['Max Temp'])
plt.ylabel("Max Temperature (C)")
plt.xlabel("Latitude")
plot_regression_line(northern_hemi_df['Lat'],northern_hemi_df['Max Temp'],estimate_coef(northern_hemi_df['Lat'],northern_hemi_df['Max Temp']))
b_0, b_1, reg_line = estimate_coef(x, y)
plt.text(1, -20, reg_line,color='red',size ='15')
# Out:
# The r-value is: 0.7290121221505323
# Text(1, -20, 'y = -0.62x + 35.54')

# %%
# Linear regression on Southern Hemisphere
corr_matrix = np.corrcoef(southern_hemi_df['Lat'],southern_hemi_df['Max Temp'])
corr = corr_matrix[0,1]
R_sq = corr**2
print('The r-value is:',R_sq)

plt.scatter(southern_hemi_df['Lat'],southern_hemi_df['Max Temp'])
plt.ylabel("Max Temperature (C)")
plt.xlabel("Latitude")
plot_regression_line(southern_hemi_df['Lat'],southern_hemi_df['Max Temp'],estimate_coef(southern_hemi_df['Lat'],southern_hemi_df['Max Temp']))
b_0, b_1, reg_line = estimate_coef(x, y)
plt.text(-55, 35, reg_line,color='red',size ='13')
# Out:
# The r-value is: 0.38432209660593464
# Text(-55, 35, 'y = -0.62x + 35.54')

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
corr_matrix = np.corrcoef(northern_hemi_df['Lat'],northern_hemi_df['Humidity'])
corr = corr_matrix[0,1]
R_sq = corr**2
print('The r-value is:',R_sq)

plt.scatter(northern_hemi_df['Lat'],northern_hemi_df['Humidity'])
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plot_regression_line(northern_hemi_df['Lat'],northern_hemi_df['Humidity'],estimate_coef(northern_hemi_df['Lat'],northern_hemi_df['Humidity']))
b_0, b_1, reg_line = estimate_coef(x, y)
plt.text(45, 15, reg_line,color='red',size ='13')
# Out:
# The r-value is: 0.11060750234347588
# Text(45, 15, 'y = -0.62x + 35.54')

# %%
# Southern Hemisphere
corr_matrix = np.corrcoef(southern_hemi_df['Lat'],southern_hemi_df['Humidity'])
corr = corr_matrix[0,1]
R_sq = corr**2
print('The r-value is:',R_sq)

plt.scatter(southern_hemi_df['Lat'],southern_hemi_df['Humidity'])
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plot_regression_line(southern_hemi_df['Lat'],southern_hemi_df['Humidity'],estimate_coef(southern_hemi_df['Lat'],southern_hemi_df['Humidity']))
b_0, b_1, reg_line = estimate_coef(x, y)
plt.text(-55, 20, reg_line,color='red',size ='15')
# Out:
# The r-value is: 0.004678693630797555
# Text(-55, 20, 'y = -0.62x + 35.54')

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
corr_matrix = np.corrcoef(northern_hemi_df['Lat'],northern_hemi_df['Cloudiness'])
corr = corr_matrix[0,1]
R_sq = corr**2
print('The r-value is:',R_sq)

plt.scatter(northern_hemi_df['Lat'],northern_hemi_df['Cloudiness'])
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plot_regression_line(northern_hemi_df['Lat'],northern_hemi_df['Cloudiness'],estimate_coef(northern_hemi_df['Lat'],northern_hemi_df['Cloudiness']))
b_0, b_1, reg_line = estimate_coef(x, y)
plt.text(-55, 20, reg_line,color='red',size ='15')
# Out:
# The r-value is: 0.06953916901742804
# Text(-55, 20, 'y = -0.62x + 35.54')

# %%
# Southern Hemisphere
corr_matrix = np.corrcoef(southern_hemi_df['Lat'],southern_hemi_df['Cloudiness'])
corr = corr_matrix[0,1]
R_sq = corr**2
print('The r-value is:',R_sq)

plt.scatter(southern_hemi_df['Lat'],southern_hemi_df['Cloudiness'])
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plot_regression_line(southern_hemi_df['Lat'],southern_hemi_df['Cloudiness'],estimate_coef(southern_hemi_df['Lat'],southern_hemi_df['Cloudiness']))
b_0, b_1, reg_line = estimate_coef(x, y)
plt.text(-55, 45, reg_line,color='red',size ='15')
# Out:
# The r-value is: 0.15668695792283618
# Text(-55, 45, 'y = -0.62x + 35.54')

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
corr_matrix = np.corrcoef(northern_hemi_df['Lat'],northern_hemi_df['Wind Speed'])
corr = corr_matrix[0,1]
R_sq = corr**2
print('The r-value is:',R_sq)

plt.scatter(northern_hemi_df['Lat'],northern_hemi_df['Wind Speed'])
plt.ylabel("Wind Speed")
plt.xlabel("Latitude")
plot_regression_line(northern_hemi_df['Lat'],northern_hemi_df['Wind Speed'],estimate_coef(northern_hemi_df['Lat'],northern_hemi_df['Wind Speed']))
b_0, b_1, reg_line = estimate_coef(x, y)
plt.text(0, 14, reg_line,color='red',size ='15')
# Out:
# The r-value is: 0.04515623480565058
# Text(0, 14, 'y = -0.62x + 35.54')

# %%
# Southern Hemisphere
corr_matrix = np.corrcoef(southern_hemi_df['Lat'],southern_hemi_df['Wind Speed'])
corr = corr_matrix[0,1]
R_sq = corr**2
print('The r-value is:',R_sq)

plt.scatter(southern_hemi_df['Lat'],southern_hemi_df['Wind Speed'])
plt.ylabel("Wind Speed")
plt.xlabel("Latitude")
plot_regression_line(southern_hemi_df['Lat'],southern_hemi_df['Wind Speed'],estimate_coef(southern_hemi_df['Lat'],southern_hemi_df['Wind Speed']))
b_0, b_1, reg_line = estimate_coef(x, y)
plt.text(-55, 10, reg_line,color='red',size ='15')
# Out:
# The r-value is: 0.10469340014361664
# Text(-55, 10, 'y = -0.62x + 35.54')

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
